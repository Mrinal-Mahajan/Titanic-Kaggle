# %%
import pandas as pd
import numpy as np
import pickle

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
from scipy.stats import skew,kurtosis

# %%
import os

# %%
os.chdir('../pickles')

# %%
numerical=pickle.load(open('numerical.pickle','rb'))
categorical = pickle.load(open('categorical.pickle','rb'))

# %%
os.chdir('../output_data')

# %%
df = pd.read_csv('train_v03.csv',header=0)

# %%
df.set_index('Id',inplace=True)

# %%
def edd(data):
    df_desc = data.describe().transpose()
    df_desc['Var'] = df_desc.index
    df_desc.reset_index(inplace=True)
    df_desc.drop('count',axis=1,inplace=True)
    df_desc['skewness'] = df_desc['Var'].apply(lambda x: skew(np.array(data.loc[data[x].notnull(),x])))
    df_desc['kurtosis'] = df_desc['Var'].apply(lambda x: kurtosis(np.array(data.loc[data[x].notnull(),x]),fisher=False))
    df_desc['99%'] = df_desc['Var'].apply(lambda x: data[x].quantile(.99))
    df_desc['95%'] = df_desc['Var'].apply(lambda x: data[x].quantile(.95))
    df_desc['90%'] = df_desc['Var'].apply(lambda x: data[x].quantile(.90))
    df_desc['10%'] = df_desc['Var'].apply(lambda x: data[x].quantile(.1))
    df_desc['5%'] = df_desc['Var'].apply(lambda x: data[x].quantile(.05))
    df_desc['1%'] = df_desc['Var'].apply(lambda x: data[x].quantile(.01))
    df_desc['mean-3sigma'] = df_desc['mean'] - 3*df_desc['std']
    df_desc['mean+3sigma'] = df_desc['mean'] + 3*df_desc['std']
    df_desc['mean-2sigma'] = df_desc['mean'] - 2*df_desc['std']
    df_desc['mean+2sigma'] = df_desc['mean'] + 2*df_desc['std']
    df_desc['type']='numeric'
    
    def is_category(col):
        return 'float' not in str(data[col].dtype) and 'int' not in str(data[col].dtype)
    
    categorical = [col for col in data.columns if is_category(col)]
    df_categorical = pd.DataFrame()
    df_categorical['Var']=np.array(categorical)
    
    df_categorical['type']='categorical'
    for col in [c for c in df_desc.columns if c not in ['Var','type']]:
        df_categorical[col]=np.nan
    for col in categorical:
        df_var = data[col].value_counts()
        df_cat = pd.DataFrame()
        df_cat['count']=df_var
        df_cat['categories']=df_var.index
        df_cat.reset_index(inplace=True)
        df_cat.sort_values(by='count',ascending=False,inplace=True)
        df_cat.set_index('categories',inplace=True)
        index_list = df_cat.index.tolist()
        for i,c in enumerate(['mean','min','1%','5%','10%','25%']):
            try:
                df_categorical.loc[df_categorical['Var']==col,c] = index_list[i]
            except:
                break
        for i,c in enumerate(['50%','75%','90%','95%','99%','max']):
            try:
                df_categorical.loc[df_categorical['Var']==col,c] = index_list[-(i+1)]
            except:
                break
        del df_var
        del df_cat
        del index_list
    df_categorical = df_categorical[df_desc.columns]
    edd = pd.concat([df_desc,df_categorical])
    del df_desc
    del df_categorical
    edd['count'] = edd['Var'].apply(lambda x: data[data[x].notnull()].shape[0])
    edd['nmiss'] = data.shape[0]-edd['count']
    edd['missing_rate'] = np.array(edd['nmiss']).astype('float')/data.shape[0] * 100
    edd['unique'] = edd['Var'].apply(lambda x: len(data[x].value_counts().index.tolist()))
    orig_cols = ['mean','min','1%','5%','10%','25%','50%','75%','90%','95%','99%','max']
    new_cols = ['mean_or_top1','min_or_top2','p1_or_top3','p5_or_top4','p10_or_top5','p25_or_top6',
                'p50_or_bottom6','p75_or_bottom5','p90_or_bottom4','p95_or_bottom3','p99_or_bottom2','max_or_bottom1']
    
    convert_dict = {}
    for i in range(len(orig_cols)):
        convert_dict[orig_cols[i]]=new_cols[i]
    edd.rename(columns=convert_dict,inplace=True)
    edd = edd[['Var','type','count','nmiss','missing_rate','unique','std','skewness','kurtosis','mean-3sigma',
               'mean-2sigma','mean_or_top1','min_or_top2','p1_or_top3','p5_or_top4','p10_or_top5','p25_or_top6',
               'p50_or_bottom6','p75_or_bottom5','p90_or_bottom4','p95_or_bottom3','p99_or_bottom2','max_or_bottom1'
              ,'mean+2sigma','mean+3sigma']]
    return edd

# %%
edd =edd(df)

# %%
def correlation(col):
    if col in numerical:
        corr_matrix = df.corr()
        return corr_matrix.loc['SalePrice',col]
    else:
        return np.nan

# %%
edd['correlation'] = edd['Var'].apply(lambda x: correlation(x))

# %%
os.chdir('../Statistics')

# %%
edd.to_csv('edd_after_treatment.csv',index=False)

# %%
df.corr()
# Out:
#                      MSSubClass  LotFrontage   LotArea  OverallQual  \
# MSSubClass             1.000000     0.012677 -0.412550    -0.074470
# LotFrontage            0.012677     1.000000 -0.025938     0.008108
# LotArea               -0.412550    -0.025938  1.000000     0.196943
# OverallQual           -0.074470     0.008108  0.196943     1.000000
# OverallCond           -0.043492    -0.004413  0.012269    -0.137753
# YearBuilt             -0.035083     0.012938  0.023636     0.527267
# YearRemodAdd          -0.007317     0.038055  0.032792     0.510709
# MasVnrArea             0.010651    -0.002107  0.015421    -0.035088
# BsmtFinSF1            -0.040947     0.022023  0.237117     0.236939
# BsmtFinSF2            -0.032647    -0.006382  0.092322    -0.005142
# BsmtUnfSF             -0.088888     0.013515  0.080650     0.344812
# TotalBsmtSF           -0.186449     0.016636  0.357765     0.559056
# 1stFlrSF              -0.210646    -0.015891  0.459018     0.483608
# 2ndFlrSF               0.012472     0.014536  0.194062     0.344499
# LowQualFinSF           0.068006     0.003875 -0.001353    -0.006654
# GrLivArea             -0.045292     0.008722  0.405285     0.590810
# BsmtFullBath           0.017594     0.024440  0.142909     0.111564
# BsmtHalfBath          -0.019276    -0.115438  0.041805    -0.078323
# FullBath               0.038329     0.029853  0.186850     0.517658
# HalfBath               0.012002     0.022620  0.060202     0.250780
# BedroomAbvGr          -0.018490    -0.000028  0.267176     0.045511
# KitchenAbvGr           0.316079     0.006349 -0.012852    -0.162586
# TotRmsAbvGrd          -0.050695    -0.007917  0.358792     0.422749
# Fireplaces            -0.107554    -0.024922  0.306163     0.401060
# GarageYrBlt            0.017193    -0.000323  0.021168     0.055512
# GarageCars            -0.096819    -0.003223  0.277952     0.616622
# GarageArea            -0.127332    -0.006746  0.329282     0.559885
# WoodDeckSF            -0.058227     0.025823  0.179770     0.286655
# OpenPorchSF           -0.045757    -0.033749  0.157122     0.410875
# EnclosedPorch         -0.022195     0.011468 -0.013979    -0.162322
#                      BsmtFinSF1  BsmtFinSF2         ...           \
# MSSubClass            -0.040947   -0.032647         ...
# LotFrontage            0.022023   -0.006382         ...
# LotArea                0.237117    0.092322         ...
# OverallQual            0.236939   -0.005142         ...
# OverallCond           -0.061603   -0.006114         ...
# YearBuilt              0.223784   -0.010077         ...
# YearRemodAdd           0.102502   -0.020799         ...
# MasVnrArea            -0.019033    0.012210         ...
# BsmtFinSF1             1.000000   -0.048146         ...
# BsmtFinSF2            -0.048146    1.000000         ...
# BsmtUnfSF             -0.377550   -0.072950         ...
# TotalBsmtSF            0.484548    0.128901         ...
# 1stFlrSF               0.397556    0.122753         ...
# 2ndFlrSF               0.000274   -0.056429         ...
# LowQualFinSF          -0.057539   -0.001866         ...
# GrLivArea              0.147882    0.018573         ...
# BsmtFullBath           0.651805    0.140745         ...
# BsmtHalfBath           0.065713    0.018230         ...
# FullBath               0.040250   -0.041068         ...
# HalfBath               0.000264   -0.005188         ...
# BedroomAbvGr          -0.088331   -0.052570         ...
# KitchenAbvGr          -0.088065   -0.033604         ...
# TotRmsAbvGrd           0.014224   -0.026490         ...
# Fireplaces             0.189407    0.049423         ...
# GarageYrBlt            0.027061    0.006979         ...
# GarageCars             0.198586   -0.018817         ...
# GarageArea             0.270434    0.009103         ...
# WoodDeckSF             0.180781    0.033338         ...
# OpenPorchSF            0.083644    0.040304         ...
# EnclosedPorch         -0.146924    0.015898         ...
# ...                         ...         ...         ...
# GarageType_dum_0      -0.237291   -0.052302         ...
# GarageType_dum_1      -0.120711   -0.063360         ...
# GarageType_dum_2      -0.005344    0.040350         ...
# GarageFinish_dum_0    -0.010620   -0.016640         ...
# GarageFinish_dum_1     0.135828   -0.018382         ...
# GarageFinish_dum_2          NaN         NaN         ...
# GarageQual_dum_0      -0.108190   -0.040613         ...
# GarageQual_dum_1      -0.111959   -0.029290         ...
# GarageQual_dum_2      -0.035688   -0.010918         ...
# GarageCond_dum_0      -0.098001   -0.039461         ...
# GarageCond_dum_1      -0.077836   -0.010005         ...
# GarageCond_dum_2      -0.052433   -0.013005         ...
# PavedDrive_dum_0      -0.177810   -0.035543         ...
# PavedDrive_dum_1      -0.071159   -0.025130         ...
# PoolQC_dum_0           0.088667    0.010938         ...
# PoolQC_dum_1           0.117662    0.010139         ...
# PoolQC_dum_2                NaN         NaN         ...
# Fence_dum_0            0.001986    0.025625         ...
# Fence_dum_1            0.006823    0.002572         ...
# Fence_dum_2            0.018343    0.006093         ...
# MiscFeature_dum_0     -0.002707   -0.030759         ...
# MiscFeature_dum_1     -0.013408   -0.008756         ...
# MiscFeature_dum_2      0.022869    0.021450         ...
# SaleType_dum_0         0.040494   -0.045611         ...
# SaleType_dum_1        -0.021679    0.031554         ...
# SaleType_dum_2         0.013916    0.012501         ...
# SaleType_dum_3         0.025808   -0.007038         ...
# SaleCondition_dum_0    0.029781   -0.053366         ...
# SaleCondition_dum_1   -0.019156    0.051492         ...
# SaleCondition_dum_2    0.007918   -0.016569         ...
#
# SaleType_dum_1                0.027125          -0.012267          -0.006126
# SaleType_dum_2                0.020246          -0.006457          -0.003224
# SaleType_dum_3                0.101871          -0.002428          -0.001212
# SaleCondition_dum_0          -0.066156          -0.019836          -0.009905
# SaleCondition_dum_1          -0.008274          -0.017443          -0.008710
# SaleCondition_dum_2          -0.019063          -0.005716          -0.002854
#
#                      SaleType_dum_0  SaleType_dum_1  SaleType_dum_2  \
# MSSubClass                 0.010836        0.034525       -0.001217
# LotFrontage                0.009452       -0.139880        0.003229
# LotArea                    0.055612       -0.019806       -0.004959
# OverallQual                0.317234       -0.077111        0.019454
# OverallCond               -0.159144       -0.045190        0.011550
# YearBuilt                  0.314112       -0.067847       -0.014237
# YearRemodAdd               0.306454       -0.128146       -0.008134
# MasVnrArea                -0.058838        0.015037        0.007915
# BsmtFinSF1                 0.040494       -0.021679        0.013916
# BsmtFinSF2                -0.045611        0.031554        0.012501
# BsmtUnfSF                  0.206287        0.002317       -0.036972
# TotalBsmtSF                0.223824        0.007847       -0.000300
# 1stFlrSF                   0.175839        0.029292       -0.010542
# 2ndFlrSF                   0.065457       -0.048672        0.008987
# LowQualFinSF              -0.016229        0.010794       -0.014561
# GrLivArea                  0.161925       -0.038642        0.018849
# BsmtFullBath              -0.012710       -0.034815       -0.006922
# BsmtHalfBath              -0.053290        0.003113        0.039269
# FullBath                   0.231898       -0.062485       -0.004759
# HalfBath                   0.052980       -0.047414       -0.004063
# BedroomAbvGr              -0.036348       -0.000511        0.049981
# KitchenAbvGr              -0.032815        0.030825        0.011215
# TotRmsAbvGrd               0.138788       -0.025136        0.015384
# Fireplaces                 0.059883       -0.076071        0.026648
# GarageYrBlt                0.013243        0.008594        0.004524
# GarageCars                 0.278341       -0.047418       -0.046727
# GarageArea                 0.245452       -0.032363       -0.048067
# WoodDeckSF                 0.035630       -0.095352        0.015483
# OpenPorchSF                0.195980       -0.068532       -0.016702
# EnclosedPorch             -0.101158        0.015755       -0.014056
# ...                             ...             ...             ...
# GarageType_dum_0          -0.160868        0.010035        0.024487
# GarageType_dum_1           0.066321       -0.013524        0.006556
# GarageType_dum_2          -0.032612        0.103837       -0.017575
# GarageFinish_dum_0         0.068114        0.009822        0.002806
# GarageFinish_dum_1         0.154540       -0.061962       -0.020337
# GarageFinish_dum_2              NaN             NaN             NaN
# GarageQual_dum_0          -0.028483       -0.005343        0.001663
# GarageQual_dum_1          -0.052853       -0.001185       -0.023049
# GarageQual_dum_2          -0.021142       -0.013721       -0.007222
# GarageCond_dum_0          -0.036632       -0.002551        0.003242
# GarageCond_dum_1          -0.040542        0.012101        0.025878
# GarageCond_dum_2          -0.025037       -0.016249       -0.008553
# PavedDrive_dum_0          -0.034816        0.016540       -0.028439
# PavedDrive_dum_1          -0.047687       -0.030948       -0.016290
# PoolQC_dum_0              -0.018902       -0.012267       -0.006457
# PoolQC_dum_1               0.031274       -0.012267       -0.006457
# PoolQC_dum_2                    NaN             NaN             NaN
# GarageCond_dum_2          -0.003216            -0.026275             0.017476
# PavedDrive_dum_0           0.074855            -0.052422             0.026687
# PavedDrive_dum_1          -0.006125            -0.030561            -0.044006
# PoolQC_dum_0              -0.002428            -0.019836             0.089784
# PoolQC_dum_1              -0.002428             0.028432            -0.017443
# PoolQC_dum_2                    NaN                  NaN                  NaN
# Fence_dum_0               -0.017328            -0.101979             0.104218
# Fence_dum_1               -0.012394            -0.070462             0.082013
# Fence_dum_2               -0.003650            -0.029819             0.009599
# MiscFeature_dum_0          0.101871            -0.066156            -0.008274
# MiscFeature_dum_1         -0.002428            -0.019836            -0.017443
# MiscFeature_dum_2         -0.001212            -0.009905            -0.008710
# SaleType_dum_0            -0.013354             0.846692            -0.053049
# SaleType_dum_1            -0.008667            -0.056744             0.312690
# SaleType_dum_2            -0.004562            -0.011359             0.053571
# SaleType_dum_3             1.000000            -0.014014             0.139189
# SaleCondition_dum_0       -0.014014             1.000000             0.085001
# SaleCondition_dum_1        0.139189             0.085001             1.000000
# SaleCondition_dum_2       -0.004038             0.083786            -0.029013
#
#                      SaleCondition_dum_2
# MSSubClass                     -0.002698
# LotFrontage                     0.002858
# LotArea                        -0.007276
# OverallQual                    -0.040703
# OverallCond                    -0.032736
# YearBuilt                      -0.023661
# YearRemodAdd                   -0.030802
# MasVnrArea                      0.007007
# BsmtFinSF1                      0.007918
# BsmtFinSF2                     -0.016569
# BsmtUnfSF                      -0.042185
# TotalBsmtSF                    -0.083652
# 1stFlrSF                        0.016056
# 2ndFlrSF                        0.005491
# LowQualFinSF                   -0.012890
# GrLivArea                       0.007820
# BsmtFullBath                    0.011502
# BsmtHalfBath                    0.063986
# FullBath                        0.046930
# HalfBath                       -0.020598
# BedroomAbvGr                    0.101913
# KitchenAbvGr                    0.163281
# TotRmsAbvGrd                    0.054104
# Fireplaces                     -0.043425
# GarageYrBlt                     0.004004
# GarageCars                     -0.015118
# GarageArea                     -0.081658
# WoodDeckSF                     -0.015297
# OpenPorchSF                    -0.057499
# EnclosedPorch                  -0.038145
# ...                                  ...
# GarageType_dum_0                0.064953
# GarageType_dum_1                0.071283
# GarageType_dum_2                0.041408
# GarageFinish_dum_0              0.003816
# GarageFinish_dum_1              0.033176
# GarageFinish_dum_2                   NaN
# GarageQual_dum_0                0.150229
# GarageQual_dum_1                0.023811
# GarageQual_dum_2               -0.006393
# GarageCond_dum_0                0.155263
# GarageCond_dum_1                0.033898
# GarageCond_dum_2               -0.007571
# PavedDrive_dum_0                0.048063
# PavedDrive_dum_1                0.046827
# PoolQC_dum_0                   -0.005716
# PoolQC_dum_1                    0.146015
# PoolQC_dum_2                         NaN
# Fence_dum_0                    -0.040795
# Fence_dum_1                     0.003095
# Fence_dum_2                    -0.008592
# MiscFeature_dum_0              -0.019063
# MiscFeature_dum_1              -0.005716
# MiscFeature_dum_2              -0.002854
# SaleType_dum_0                 -0.031440
# SaleType_dum_1                 -0.020404
# SaleType_dum_2                 -0.010740
# SaleType_dum_3                 -0.004038
# SaleCondition_dum_0             0.083786
# SaleCondition_dum_1            -0.029013
# SaleCondition_dum_2             1.000000
#
# [166 rows x 166 columns]

# %%
def inter_correlation_clusters(data,cutoff=.7):
    correlations=data.corr()
    graph={}
    columns=data.columns
    for i in range(len(columns)):
        graph[i]=[]
        for j in range(len(columns)):
            if i!=j and np.abs(correlations.iloc[i,j])>cutoff:
                graph[i].append(j)
    
    tree_set={}
    component = 0
    visited = [0 for i in range(len(columns))]
    def dfs(i):
        visited[i]=1
        try:
            tree_set[component].append(i)
        except KeyError:
            tree_set[component] = [i]
            
        for j in graph[i]:
            if visited[j]==0:
                dfs(j)
                
    tree_cluster={}
    for key in list(tree_set.keys()):
        tree_cluster[key] = [columns[i] for i in tree_set[key]]
        
    return tree_cluster

# %%
def varclus(data):
    columns = []
    correlations=data.corr()
    clusters= inter_correlation_clusters(data)
    print(clusters)
    
    cols = list(data.columns)
    
    def distance(c1,c2):
        return np.max([[np.abs(correlations.loc[i,j]) for i in clusters[c1]] for j in clusters[c2]])
    
    def next_closest(c):
        minima=0
        point=c
        for c1 in [i for i in list(clusters.keys()) if i!=c]:
            dist = distance(c,c1)
            if dist>minima:
                minima=dist
                point=c1
        return point
    
    def get_squared_ratio(col,own_cluster,next_cluster):
        y = np.array(data[col])
        x = np.array(data[own_cluster].drop(col,axis=1))
        model=LinearRegression()
        model.fit(x,y)
        y_pred = list(model.predict(x))
        del x
        del model
        r2_own = r2_score(y,y_pred)
        del y_pred
        x = np.array(data[next_cluster])
        model=LinearRegression()
        model.fit(x,y)
        y_pred = list(model.predict(x))
        del x
        del model
        r2_next = r2_score(y,y_pred)
        del y
        del y_pred
        
        return float(1-r2_own)/(1-r2_next)
    
    for c1 in list(clusters.keys()):
        if len(clusters[c1])>1:
            own_cluster = clusters[c1]
            next_cluster = clusters[next_closest(c1)]
            ration=np.inf
            for col in clusters[c1]:
                col_ratio = get_squared_ratio(col,own_cluster,next_cluster)
                if col_ratio<ratio:
                    ratio=col_ratio
                    clust_col=col
            columns.append(clust_col)
        else:
            columns.append(clusters[c1][0])
            
    return columns

# %%
columns = varclus(df.drop(['SalePrice'],axis=1))
# Out:
# {}

# %%
for col in df.columns:
    if True in np.isinf(np.array(df[col])):
        print col

# %% [markdown]
# # Variance Inflation Factor

# %%
df.shape
# Out:
# (1168, 166)

# %%
from patsy import dmatrices
import statsmodels
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def variance_inflation(data):
    vif = pd.DataFrame()
    vif['features'] = data.columns
    vif['vif factor'] = [variance_inflation_factor(data.values, i) for i in range(data.shape[1])]
    vif.sort_values(by='vif factor',ascending=False,inplace=True)
    vif.reset_index(inplace=True)
    vif.drop(['index'],axis=1,inplace=True)
    print(vif)
    return tuple(vif.loc[0,:].values)

# %%
vif_drop_cols=[]

# %%
def vif_reduction(data,limit=2.5):
    vif = variance_inflation(data)
    if vif[1]<=limit:
        return
    else:
        data.drop(vif[0],axis=1,inplace=True)
        vif_drop_cols.append(vif[0])
        print(vif[0]+' dropped')
        del vif
        vif_reduction(data,limit=limit)

# %%
vif_reduction(df.drop(['SalePrice'],axis=1))
# Out:
#                  features    vif factor
# 0        MasVnrType_dum_2           inf
# 1             GarageYrBlt  6.868049e+09
# 2    Utilities_dum_AllPub  2.254263e+02
# 3             TotalBsmtSF  4.572667e+00
# 4              GarageCars  4.115945e+00
# 5              BsmtFinSF1  3.982912e+00
# 6               BsmtUnfSF  3.855188e+00
# 7                1stFlrSF  3.393858e+00
# 8               GrLivArea  3.230451e+00
# 9               YearBuilt  2.822623e+00
# 10        ExterCond_dum_2  2.695650e+00
# 11            OverallQual  2.339259e+00
# 12         BldgType_dum_2  2.250005e+00
# 13           YearRemodAdd  2.100039e+00
# 14               2ndFlrSF  2.011320e+00
# 15               FullBath  1.978107e+00
# 16           TotRmsAbvGrd  1.962866e+00
# 17           BsmtFullBath  1.902620e+00
# 18         BldgType_dum_0  1.856053e+00
# 19       HouseStyle_dum_0  1.849900e+00
# 20             GarageArea  1.743522e+00
# 21       GarageType_dum_0  1.660863e+00
# 22        ExterQual_dum_0  1.645408e+00
# 23         BsmtCond_dum_2  1.598045e+00
# 24                LotArea  1.562404e+00
# 25            OverallCond  1.557205e+00
# 26       Foundation_dum_1  1.542445e+00
# 27       Foundation_dum_0  1.521224e+00
# 28      Exterior1st_dum_1  1.474377e+00
# 29           BedroomAbvGr  1.449848e+00
# ..                    ...           ...
# 135      Foundation_dum_2  1.023849e+00
# 136   SaleCondition_dum_2  1.023835e+00
# 137      Condition1_dum_0  1.022911e+00
# 138           LotFrontage  1.020723e+00
# 139      Condition2_dum_2  1.020654e+00
# 140      Condition1_dum_2  1.020539e+00
# 141                MoSold  1.016286e+00
# 142       Street_dum_Pave  1.015816e+00
# 143           Fence_dum_2  1.015217e+00
# 144       LotConfig_dum_0  1.014417e+00
# 145            MasVnrArea  1.014155e+00
# 146       RoofStyle_dum_2  1.013387e+00
# 147        SaleType_dum_3  1.012611e+00
# 148             3SsnPorch  1.011928e+00
# 149     MiscFeature_dum_1  1.011198e+00
# 150       HeatingQC_dum_2  1.011132e+00
# 151       LotConfig_dum_2  1.009212e+00
# 152        SaleType_dum_2  1.008128e+00
# 153      Electrical_dum_2  1.007737e+00
# 154      Condition1_dum_3  1.002402e+00
# 155                YrSold  6.536638e-03
# 156        LotShape_dum_2           NaN
# 157     LandContour_dum_2           NaN
# 158      Condition2_dum_3           NaN
# 159      HouseStyle_dum_3           NaN
# 160     Exterior2nd_dum_4           NaN
# 161       ExterQual_dum_2           NaN
# 162     KitchenQual_dum_2           NaN
# 163    GarageFinish_dum_2           NaN
# 164          PoolQC_dum_2           NaN
#
# [165 rows x 2 columns]
# MasVnrType_dum_2 dropped
#                  features    vif factor
# 0             GarageYrBlt  1.570667e+07
# 1    Utilities_dum_AllPub  2.257746e+02
# 2             TotalBsmtSF  4.562614e+00
# 3              GarageCars  4.118561e+00
# 4              BsmtFinSF1  3.977505e+00
# 5               BsmtUnfSF  3.880342e+00
# 6               GrLivArea  3.469482e+00
# 7                1stFlrSF  3.388424e+00
# 8               YearBuilt  2.874833e+00
# 9         ExterCond_dum_2  2.699234e+00
# 10            OverallQual  2.378264e+00
# 11         BldgType_dum_2  2.251305e+00
# 12           YearRemodAdd  2.092396e+00
# 13               FullBath  1.983614e+00
# 14           TotRmsAbvGrd  1.915738e+00
# 15           BsmtFullBath  1.901469e+00
# 16       HouseStyle_dum_0  1.855044e+00
# 17         BldgType_dum_0  1.790813e+00
# 18           BedroomAbvGr  1.734895e+00
# 19             GarageArea  1.724505e+00
# 20       GarageType_dum_0  1.665161e+00
# 21        ExterQual_dum_0  1.645809e+00
# 22                LotArea  1.642165e+00
# 23         BsmtCond_dum_2  1.596554e+00
# 24            OverallCond  1.556492e+00
# 25       Foundation_dum_1  1.545541e+00
# 26       Foundation_dum_0  1.538474e+00
# 27         BsmtQual_dum_2  1.536557e+00
# 28      Exterior1st_dum_1  1.475449e+00
# 29     BsmtExposure_dum_2  1.431115e+00
# ..                    ...           ...
# 134   SaleCondition_dum_2  1.024882e+00
# 135      Condition2_dum_0  1.024843e+00
# 136      Foundation_dum_2  1.024021e+00
# 137           LotFrontage  1.020846e+00
# 138      Condition2_dum_2  1.020789e+00
# 139             3SsnPorch  1.016027e+00
# 140                MoSold  1.015998e+00
# 141      Condition1_dum_2  1.015751e+00
# 142       LotConfig_dum_0  1.014970e+00
# 143           Fence_dum_2  1.014703e+00
# 144            MasVnrArea  1.014097e+00
# 145        SaleType_dum_3  1.013200e+00
# 146       Street_dum_Pave  1.011882e+00
# 147     MiscFeature_dum_1  1.011484e+00
# 148       RoofStyle_dum_2  1.011061e+00
# 149        SaleType_dum_2  1.010324e+00
# 150       HeatingQC_dum_2  1.009829e+00
# 151       LotConfig_dum_2  1.009352e+00
# 152      Electrical_dum_2  1.007412e+00
# 153      Condition1_dum_3  1.002612e+00
# 154                YrSold  6.561890e-03
# 155        LotShape_dum_2           NaN
# 156     LandContour_dum_2           NaN
# 157      Condition2_dum_3           NaN
# 158      HouseStyle_dum_3           NaN
# 159     Exterior2nd_dum_4           NaN
# 160       ExterQual_dum_2           NaN
# 161     KitchenQual_dum_2           NaN
# 162    GarageFinish_dum_2           NaN
# 163          PoolQC_dum_2           NaN
#
# [164 rows x 2 columns]
# GarageYrBlt dropped
#                  features    vif factor
# 0          BsmtQual_dum_2  4.898062e+08
# 1      BsmtExposure_dum_2  3.881713e+08
# 2             LotFrontage  2.841853e+02
# 3    Utilities_dum_AllPub  2.816083e+02
# 4                 MiscVal  1.905980e+01
# 5               GrLivArea  1.703336e+01
# 6                PoolArea  1.696489e+01
# 7       MiscFeature_dum_0  1.589275e+01
# 8              MSSubClass  1.547805e+01
# 9              Fireplaces  1.251233e+01
# 10            TotalBsmtSF  1.236966e+01
# 11               1stFlrSF  1.119321e+01
# 12              YearBuilt  1.051143e+01
# 13         BldgType_dum_2  9.870077e+00
# 14           PoolQC_dum_0  8.687173e+00
# 15             BsmtFinSF1  8.351992e+00
# 16           PoolQC_dum_1  8.301870e+00
# 17       GarageCond_dum_0  7.847360e+00
# 18       GarageQual_dum_0  7.816244e+00
# 19      FireplaceQu_dum_0  7.422994e+00
# 20         BldgType_dum_0  7.402178e+00
# 21      FireplaceQu_dum_1  7.365751e+00
# 22           TotRmsAbvGrd  6.316849e+00
# 23             GarageArea  5.971571e+00
# 24      Exterior2nd_dum_0  5.752796e+00
# 25         SaleType_dum_0  5.591345e+00
# 26      Exterior1st_dum_0  5.445661e+00
# 27    SaleCondition_dum_0  5.305925e+00
# 28             GarageCars  5.268161e+00
# 29              BsmtUnfSF  5.086171e+00
# ..                    ...           ...
# 133    BsmtExposure_dum_0  1.338079e+00
# 134      Functional_dum_2  1.327839e+00
# 135           Fence_dum_1  1.327549e+00
# 136           ScreenPorch  1.322881e+00
# 137        SaleType_dum_3  1.314263e+00
# 138      Foundation_dum_2  1.309148e+00
# 139       Street_dum_Pave  1.307300e+00
# 140        SaleType_dum_2  1.292632e+00
# 141         Heating_dum_2  1.252427e+00
# 142                YrSold  1.246952e+00
# 143      PavedDrive_dum_1  1.239949e+00
# 144       HeatingQC_dum_2  1.209740e+00
# 145       ExterCond_dum_2  1.208313e+00
# 146       LotConfig_dum_2  1.189177e+00
# 147                MoSold  1.177769e+00
# 148             3SsnPorch  1.163328e+00
# 149       LotConfig_dum_0  1.160000e+00
# 150           Fence_dum_2  1.154870e+00
# 151            MasVnrArea  1.071952e+00
# 152      Electrical_dum_2  1.061171e+00
# 153      Condition1_dum_3  1.042167e+00
# 154        LotShape_dum_2           NaN
# 155     LandContour_dum_2           NaN
# 156      Condition2_dum_3           NaN
# 157      HouseStyle_dum_3           NaN
# 158     Exterior2nd_dum_4           NaN
# 159       ExterQual_dum_2           NaN
# 160     KitchenQual_dum_2           NaN
# 161    GarageFinish_dum_2           NaN
# 162          PoolQC_dum_2           NaN
#
# [163 rows x 2 columns]
# BsmtQual_dum_2 dropped
#                  features  vif factor
# 0             LotFrontage  283.905657
# 1    Utilities_dum_AllPub  281.608268
# 2                 MiscVal   19.059800
# 3               GrLivArea   17.033363
# 4                PoolArea   16.964891
# 5       MiscFeature_dum_0   15.892750
# 6              MSSubClass   15.478044
# 7              Fireplaces   12.512330
# 8             TotalBsmtSF   12.369662
# 9                1stFlrSF   11.193209
# 10              YearBuilt   10.511428
# 11         BldgType_dum_2    9.870077
# 12           PoolQC_dum_0    8.687173
# 13             BsmtFinSF1    8.351992
# 14           PoolQC_dum_1    8.301870
# 15       GarageCond_dum_0    7.847359
# 16       GarageQual_dum_0    7.816244
# 17      FireplaceQu_dum_0    7.422994
# 18         BldgType_dum_0    7.402178
# 19      FireplaceQu_dum_1    7.365751
# 20           TotRmsAbvGrd    6.316849
# 21     BsmtExposure_dum_2    6.190517
# 22             GarageArea    5.971571
# 23      Exterior2nd_dum_0    5.752796
# 24         SaleType_dum_0    5.591345
# 25      Exterior1st_dum_0    5.445661
# 26    SaleCondition_dum_0    5.305925
# 27             GarageCars    5.268161
# 28              BsmtUnfSF    5.086171
# 29            OverallQual    4.900194
# ..                    ...         ...
# 132    BsmtExposure_dum_0    1.338079
# 133      Functional_dum_2    1.327839
# 134           Fence_dum_1    1.327549
# 135           ScreenPorch    1.322881
# 136        SaleType_dum_3    1.314263
# 137      Foundation_dum_2    1.309148
# 138       Street_dum_Pave    1.307300
# 139        SaleType_dum_2    1.292632
# 140         Heating_dum_2    1.252427
# 141                YrSold    1.246952
# 142      PavedDrive_dum_1    1.239949
# 143       HeatingQC_dum_2    1.209740
# 144       ExterCond_dum_2    1.208313
# 145       LotConfig_dum_2    1.189177
# 146                MoSold    1.177769
# 147             3SsnPorch    1.163328
# 148       LotConfig_dum_0    1.160000
# 149           Fence_dum_2    1.154870
# 150            MasVnrArea    1.071952
# 151      Electrical_dum_2    1.061171
# 152      Condition1_dum_3    1.042167
# 153        LotShape_dum_2         NaN
# 154     LandContour_dum_2         NaN
# 155      Condition2_dum_3         NaN
# 156      HouseStyle_dum_3         NaN
# 157     Exterior2nd_dum_4         NaN
# 158       ExterQual_dum_2         NaN
# 159     KitchenQual_dum_2         NaN
# 160    GarageFinish_dum_2         NaN
# 161          PoolQC_dum_2         NaN
#
# [162 rows x 2 columns]
# LotFrontage dropped
#                  features  vif factor
# 0                 MiscVal   19.035208
# 1               GrLivArea   17.033010
# 2                PoolArea   16.964434
# 3       MiscFeature_dum_0   15.867091
# 4              MSSubClass   15.477710
# 5              Fireplaces   12.511662
# 6             TotalBsmtSF   12.320880
# 7                1stFlrSF   11.161190
# 8               YearBuilt   10.287827
# 9          BldgType_dum_2    9.865281
# 10           PoolQC_dum_0    8.683263
# 11             BsmtFinSF1    8.343564
# 12           PoolQC_dum_1    8.300477
# 13       GarageCond_dum_0    7.846280
# 14       GarageQual_dum_0    7.801054
# 15      FireplaceQu_dum_0    7.422368
# 16         BldgType_dum_0    7.394460
# 17      FireplaceQu_dum_1    7.365682
# 18           TotRmsAbvGrd    6.304668
# 19     BsmtExposure_dum_2    6.120825
# 20             GarageArea    5.970632
# 21      Exterior2nd_dum_0    5.752380
# 22         SaleType_dum_0    5.583653
# 23      Exterior1st_dum_0    5.445495
# 24    SaleCondition_dum_0    5.299854
# 25             GarageCars    5.267111
# 26              BsmtUnfSF    5.085016
# 27            OverallQual    4.899629
# 28               2ndFlrSF    4.853866
# 29      Exterior1st_dum_2    4.649988
# ..                    ...         ...
# 131           Fence_dum_1    1.327546
# 132      Functional_dum_2    1.325759
# 133           ScreenPorch    1.322700
# 134        SaleType_dum_3    1.312047
# 135      Foundation_dum_2    1.307149
# 136       Street_dum_Pave    1.302972
# 137        SaleType_dum_2    1.292195
# 138         Heating_dum_2    1.251659
# 139      PavedDrive_dum_1    1.239949
# 140  Utilities_dum_AllPub    1.211358
# 141       HeatingQC_dum_2    1.209645
# 142       ExterCond_dum_2    1.208258
# 143       LotConfig_dum_2    1.188660
# 144                MoSold    1.166125
# 145             3SsnPorch    1.163187
# 146       LotConfig_dum_0    1.159967
# 147           Fence_dum_2    1.154126
# 148            MasVnrArea    1.071166
# 149      Electrical_dum_2    1.061102
# 150      Condition1_dum_3    1.042165
# 151                YrSold    0.037091
# 152        LotShape_dum_2         NaN
# 153     LandContour_dum_2         NaN
# 154      Condition2_dum_3         NaN
# 155      HouseStyle_dum_3         NaN
# 156     Exterior2nd_dum_4         NaN
# 157       ExterQual_dum_2         NaN
# 158     KitchenQual_dum_2         NaN
# 159    GarageFinish_dum_2         NaN
# 160          PoolQC_dum_2         NaN
#
# [161 rows x 2 columns]
# MiscVal dropped
#                  features  vif factor
# 0               GrLivArea   17.030358
# 1                PoolArea   16.946515
# 2              MSSubClass   15.471709
# 3              Fireplaces   12.511251
# 4             TotalBsmtSF   12.228516
# 5                1stFlrSF   11.093386
# 6               YearBuilt   10.272607
# 7          BldgType_dum_2    9.860498
# 8            PoolQC_dum_0    8.680191
# 9              BsmtFinSF1    8.342478
# 10           PoolQC_dum_1    8.293944
# 11       GarageCond_dum_0    7.846187
# 12       GarageQual_dum_0    7.800419
# 13      FireplaceQu_dum_0    7.421905
# 14         BldgType_dum_0    7.393847
# 15      FireplaceQu_dum_1    7.358991
# 16           TotRmsAbvGrd    6.303387
# 17     BsmtExposure_dum_2    6.088441
# 18             GarageArea    5.968545
# 19      Exterior2nd_dum_0    5.750391
# 20         SaleType_dum_0    5.581903
# 21      Exterior1st_dum_0    5.429640
# 22    SaleCondition_dum_0    5.298209
# 23             GarageCars    5.261273
# 24              BsmtUnfSF    5.084788
# 25            OverallQual    4.899626
# 26               2ndFlrSF    4.853222
# 27      Exterior1st_dum_2    4.645121
# 28                LotArea    4.460357
# 29      Exterior2nd_dum_2    4.278363
# ..                    ...         ...
# 130     MiscFeature_dum_1    1.320169
# 131           ScreenPorch    1.316020
# 132       Street_dum_Pave    1.302971
# 133        SaleType_dum_2    1.292192
# 134      Foundation_dum_2    1.288989
# 135     MiscFeature_dum_0    1.279212
# 136         Heating_dum_2    1.251102
# 137      PavedDrive_dum_1    1.239224
# 138  Utilities_dum_AllPub    1.211219
# 139       HeatingQC_dum_2    1.209034
# 140       ExterCond_dum_2    1.198963
# 141       LotConfig_dum_2    1.188630
# 142                MoSold    1.165980
# 143             3SsnPorch    1.163187
# 144       LotConfig_dum_0    1.159272
# 145           Fence_dum_2    1.154036
# 146        SaleType_dum_3    1.129645
# 147            MasVnrArea    1.071139
# 148      Electrical_dum_2    1.061060
# 149      Condition1_dum_3    1.042144
# 150                YrSold    0.037090
# 151        LotShape_dum_2         NaN
# 152     LandContour_dum_2         NaN
# 153      Condition2_dum_3         NaN
# 154      HouseStyle_dum_3         NaN
# 155     Exterior2nd_dum_4         NaN
# 156       ExterQual_dum_2         NaN
# 157     KitchenQual_dum_2         NaN
# 158    GarageFinish_dum_2         NaN
# 159          PoolQC_dum_2         NaN
#
# [160 rows x 2 columns]
# GrLivArea dropped
#                  features  vif factor
# 0                PoolArea   16.737284
# 1              MSSubClass   15.391355
# 2             TotalBsmtSF   12.216031
# 3              Fireplaces   12.137728
# 4               YearBuilt   10.066055
# 5          BldgType_dum_2    9.834757
# 6            PoolQC_dum_0    8.672514
# 7                1stFlrSF    8.449049
# 8              BsmtFinSF1    8.331519
# 9            PoolQC_dum_1    8.094230
# 10       GarageCond_dum_0    7.841026
# 11       GarageQual_dum_0    7.799441
# 12         BldgType_dum_0    7.385434
# 13      FireplaceQu_dum_1    7.297436
# 14      FireplaceQu_dum_0    7.297134
# 15     BsmtExposure_dum_2    6.086473
# 16             GarageArea    5.930334
# 17      Exterior2nd_dum_0    5.737999
# 18         SaleType_dum_0    5.579436
# 19           TotRmsAbvGrd    5.475493
# 20      Exterior1st_dum_0    5.428615
# 21    SaleCondition_dum_0    5.291046
# 22             GarageCars    5.221901
# 23              BsmtUnfSF    5.083301
# 24            OverallQual    4.785865
# 25      Exterior1st_dum_2    4.638713
# 26                LotArea    4.447664
# 27      Exterior2nd_dum_2    4.274237
# 28               2ndFlrSF    3.712286
# 29       HouseStyle_dum_0    3.516996
# ..                    ...         ...
# 129     MiscFeature_dum_1    1.319216
# 130           ScreenPorch    1.315540
# 131       Street_dum_Pave    1.302609
# 132        SaleType_dum_2    1.292135
# 133      Foundation_dum_2    1.285849
# 134     MiscFeature_dum_0    1.279106
# 135         Heating_dum_2    1.251064
# 136      PavedDrive_dum_1    1.239151
# 137       HeatingQC_dum_2    1.207384
# 138  Utilities_dum_AllPub    1.205716
# 139       ExterCond_dum_2    1.198837
# 140       LotConfig_dum_2    1.187927
# 141                MoSold    1.163707
# 142       LotConfig_dum_0    1.158962
# 143             3SsnPorch    1.158462
# 144           Fence_dum_2    1.153331
# 145        SaleType_dum_3    1.128902
# 146            MasVnrArea    1.071046
# 147      Electrical_dum_2    1.060554
# 148      Condition1_dum_3    1.041526
# 149                YrSold    0.036659
# 150        LotShape_dum_2         NaN
# 151     LandContour_dum_2         NaN
# 152      Condition2_dum_3         NaN
# 153      HouseStyle_dum_3         NaN
# 154     Exterior2nd_dum_4         NaN
# 155       ExterQual_dum_2         NaN
# 156     KitchenQual_dum_2         NaN
# 157    GarageFinish_dum_2         NaN
# 158          PoolQC_dum_2         NaN
#
# [159 rows x 2 columns]
# PoolArea dropped
#                  features  vif factor
# 0              MSSubClass   15.374479
# 1             TotalBsmtSF   12.172465
# 2              Fireplaces   12.044081
# 3               YearBuilt   10.002363
# 4          BldgType_dum_2    9.829321
# 5                1stFlrSF    8.383843
# 6              BsmtFinSF1    8.331183
# 7        GarageCond_dum_0    7.816063
# 8        GarageQual_dum_0    7.762833
# 9          BldgType_dum_0    7.383377
# 10      FireplaceQu_dum_0    7.246352
# 11      FireplaceQu_dum_1    7.234194
# 12     BsmtExposure_dum_2    6.086268
# 13             GarageArea    5.926376
# 14      Exterior2nd_dum_0    5.737544
# 15         SaleType_dum_0    5.570783
# 16           TotRmsAbvGrd    5.453781
# 17      Exterior1st_dum_0    5.427854
# 18    SaleCondition_dum_0    5.272838
# 19             GarageCars    5.213558
# 20              BsmtUnfSF    5.083291
# 21            OverallQual    4.782757
# 22      Exterior1st_dum_2    4.632496
# 23                LotArea    4.447621
# 24      Exterior2nd_dum_2    4.263739
# 25               2ndFlrSF    3.566582
# 26       HouseStyle_dum_0    3.511852
# 27           YearRemodAdd    3.316262
# 28               FullBath    3.279215
# 29       Foundation_dum_0    3.177933
# ..                    ...         ...
# 128     MiscFeature_dum_1    1.319215
# 129           ScreenPorch    1.314238
# 130       Street_dum_Pave    1.301484
# 131        SaleType_dum_2    1.292134
# 132      Foundation_dum_2    1.285524
# 133     MiscFeature_dum_0    1.278982
# 134         Heating_dum_2    1.250817
# 135      PavedDrive_dum_1    1.239092
# 136       HeatingQC_dum_2    1.207365
# 137  Utilities_dum_AllPub    1.205713
# 138       ExterCond_dum_2    1.198292
# 139       LotConfig_dum_2    1.187859
# 140                MoSold    1.163452
# 141       LotConfig_dum_0    1.158958
# 142             3SsnPorch    1.157992
# 143           Fence_dum_2    1.152382
# 144        SaleType_dum_3    1.128763
# 145            MasVnrArea    1.071027
# 146      Electrical_dum_2    1.060009
# 147      Condition1_dum_3    1.041526
# 148                YrSold    0.036656
# 149        LotShape_dum_2         NaN
# 150     LandContour_dum_2         NaN
# 151      Condition2_dum_3         NaN
# 152      HouseStyle_dum_3         NaN
# 153     Exterior2nd_dum_4         NaN
# 154       ExterQual_dum_2         NaN
# 155     KitchenQual_dum_2         NaN
# 156    GarageFinish_dum_2         NaN
# 157          PoolQC_dum_2         NaN
#
# [158 rows x 2 columns]
# MSSubClass dropped
#                  features  vif factor
# 0             TotalBsmtSF   12.154756
# 1              Fireplaces   12.041255
# 2               YearBuilt   10.001731
# 3                1stFlrSF    8.349880
# 4              BsmtFinSF1    8.228404
# 5        GarageCond_dum_0    7.812039
# 6        GarageQual_dum_0    7.747868
# 7       FireplaceQu_dum_0    7.246087
# 8       FireplaceQu_dum_1    7.234194
# 9      BsmtExposure_dum_2    6.085931
# 10             GarageArea    5.924854
# 11      Exterior2nd_dum_0    5.736957
# 12         SaleType_dum_0    5.561556
# 13           TotRmsAbvGrd    5.448754
# 14      Exterior1st_dum_0    5.420913
# 15    SaleCondition_dum_0    5.272280
# 16             GarageCars    5.213459
# 17              BsmtUnfSF    5.029900
# 18            OverallQual    4.782691
# 19      Exterior1st_dum_2    4.630591
# 20                LotArea    4.381781
# 21      Exterior2nd_dum_2    4.263501
# 22               2ndFlrSF    3.556724
# 23           YearRemodAdd    3.314944
# 24               FullBath    3.278735
# 25       HouseStyle_dum_0    3.183835
# 26       Foundation_dum_0    3.174509
# 27         BldgType_dum_0    3.049747
# 28           BedroomAbvGr    3.008469
# 29     GarageFinish_dum_1    2.969269
# ..                    ...         ...
# 127      Functional_dum_2    1.313688
# 128           ScreenPorch    1.310346
# 129       Street_dum_Pave    1.301479
# 130      Foundation_dum_2    1.284421
# 131        SaleType_dum_2    1.283791
# 132     MiscFeature_dum_0    1.278801
# 133         Heating_dum_2    1.250732
# 134      PavedDrive_dum_1    1.238517
# 135       HeatingQC_dum_2    1.204960
# 136  Utilities_dum_AllPub    1.201123
# 137       ExterCond_dum_2    1.198175
# 138       LotConfig_dum_2    1.187466
# 139                MoSold    1.163451
# 140             3SsnPorch    1.157984
# 141       LotConfig_dum_0    1.157962
# 142           Fence_dum_2    1.152119
# 143        SaleType_dum_3    1.128713
# 144            MasVnrArea    1.069144
# 145      Electrical_dum_2    1.059901
# 146      Condition1_dum_3    1.041508
# 147                YrSold    0.036654
# 148        LotShape_dum_2         NaN
# 149     LandContour_dum_2         NaN
# 150      Condition2_dum_3         NaN
# 151      HouseStyle_dum_3         NaN
# 152     Exterior2nd_dum_4         NaN
# 153       ExterQual_dum_2         NaN
# 154     KitchenQual_dum_2         NaN
# 155    GarageFinish_dum_2         NaN
# 156          PoolQC_dum_2         NaN
#
# [157 rows x 2 columns]
# TotalBsmtSF dropped
#                  features  vif factor
# 0              Fireplaces   12.041139
# 1               YearBuilt    9.983040
# 2        GarageCond_dum_0    7.810619
# 3        GarageQual_dum_0    7.747113
# 4       FireplaceQu_dum_0    7.245735
# 5       FireplaceQu_dum_1    7.229506
# 6                1stFlrSF    6.119429
# 7              BsmtFinSF1    6.064155
# 8              GarageArea    5.903536
# 9       Exterior2nd_dum_0    5.734733
# 10         SaleType_dum_0    5.559083
# 11           TotRmsAbvGrd    5.441690
# 12      Exterior1st_dum_0    5.413706
# 13    SaleCondition_dum_0    5.267865
# 14             GarageCars    5.212535
# 15     BsmtExposure_dum_2    4.973440
# 16            OverallQual    4.758858
# 17      Exterior1st_dum_2    4.622946
# 18                LotArea    4.378913
# 19      Exterior2nd_dum_2    4.256497
# 20              BsmtUnfSF    3.650025
# 21               2ndFlrSF    3.521181
# 22           YearRemodAdd    3.297559
# 23               FullBath    3.278729
# 24       Foundation_dum_0    3.173108
# 25       HouseStyle_dum_0    3.096605
# 26         BldgType_dum_0    3.041077
# 27           BedroomAbvGr    3.000982
# 28     GarageFinish_dum_1    2.969263
# 29       GarageType_dum_0    2.716614
# ..                    ...         ...
# 126      Functional_dum_2    1.311363
# 127           ScreenPorch    1.310030
# 128       Street_dum_Pave    1.300106
# 129        SaleType_dum_2    1.283714
# 130      Foundation_dum_2    1.279046
# 131     MiscFeature_dum_0    1.277961
# 132         Heating_dum_2    1.250425
# 133      PavedDrive_dum_1    1.238283
# 134       HeatingQC_dum_2    1.203255
# 135  Utilities_dum_AllPub    1.200434
# 136       ExterCond_dum_2    1.197453
# 137       LotConfig_dum_2    1.186148
# 138                MoSold    1.158098
# 139             3SsnPorch    1.157973
# 140       LotConfig_dum_0    1.157934
# 141           Fence_dum_2    1.151643
# 142        SaleType_dum_3    1.127484
# 143            MasVnrArea    1.068409
# 144      Electrical_dum_2    1.058693
# 145      Condition1_dum_3    1.041312
# 146                YrSold    0.036646
# 147        LotShape_dum_2         NaN
# 148     LandContour_dum_2         NaN
# 149      Condition2_dum_3         NaN
# 150      HouseStyle_dum_3         NaN
# 151     Exterior2nd_dum_4         NaN
# 152       ExterQual_dum_2         NaN
# 153     KitchenQual_dum_2         NaN
# 154    GarageFinish_dum_2         NaN
# 155          PoolQC_dum_2         NaN
#
# [156 rows x 2 columns]
# Fireplaces dropped
#                  features  vif factor
# 0               YearBuilt    9.876492
# 1        GarageCond_dum_0    7.801032
# 2        GarageQual_dum_0    7.742344
# 3                1stFlrSF    6.081324
# 4              BsmtFinSF1    6.063815
# 5              GarageArea    5.893061
# 6       Exterior2nd_dum_0    5.734211
# 7          SaleType_dum_0    5.557481
# 8            TotRmsAbvGrd    5.416116
# 9       Exterior1st_dum_0    5.413535
# 10    SaleCondition_dum_0    5.267618
# 11             GarageCars    5.212365
# 12     BsmtExposure_dum_2    4.970966
# 13            OverallQual    4.678530
# 14      Exterior1st_dum_2    4.622103
# 15                LotArea    4.372653
# 16      Exterior2nd_dum_2    4.255906
# 17              BsmtUnfSF    3.649767
# 18               2ndFlrSF    3.503351
# 19           YearRemodAdd    3.287561
# 20               FullBath    3.272910
# 21       Foundation_dum_0    3.171393
# 22       HouseStyle_dum_0    3.091468
# 23         BldgType_dum_0    3.037796
# 24           BedroomAbvGr    2.983420
# 25     GarageFinish_dum_1    2.962479
# 26       Foundation_dum_1    2.715848
# 27       GarageType_dum_0    2.713214
# 28       GarageCond_dum_2    2.708543
# 29           KitchenAbvGr    2.703855
# ..                    ...         ...
# 125       Street_dum_Pave    1.300090
# 126           ScreenPorch    1.298209
# 127        SaleType_dum_2    1.283644
# 128      Foundation_dum_2    1.277677
# 129     MiscFeature_dum_0    1.277130
# 130         Heating_dum_2    1.250196
# 131      PavedDrive_dum_1    1.238238
# 132       HeatingQC_dum_2    1.202901
# 133  Utilities_dum_AllPub    1.200275
# 134       ExterCond_dum_2    1.196196
# 135       LotConfig_dum_2    1.186064
# 136     FireplaceQu_dum_2    1.180132
# 137                MoSold    1.158048
# 138             3SsnPorch    1.157683
# 139       LotConfig_dum_0    1.157162
# 140           Fence_dum_2    1.146025
# 141        SaleType_dum_3    1.127461
# 142            MasVnrArea    1.068404
# 143      Electrical_dum_2    1.058499
# 144      Condition1_dum_3    1.041274
# 145                YrSold    0.036461
# 146        LotShape_dum_2         NaN
# 147     LandContour_dum_2         NaN
# 148      Condition2_dum_3         NaN
# 149      HouseStyle_dum_3         NaN
# 150     Exterior2nd_dum_4         NaN
# 151       ExterQual_dum_2         NaN
# 152     KitchenQual_dum_2         NaN
# 153    GarageFinish_dum_2         NaN
# 154          PoolQC_dum_2         NaN
#
# [155 rows x 2 columns]
# YearBuilt dropped
#                  features  vif factor
# 0        GarageCond_dum_0    7.771582
# 1        GarageQual_dum_0    7.740281
# 2                1stFlrSF    6.019195
# 3              BsmtFinSF1    5.998873
# 4              GarageArea    5.873154
# 5       Exterior2nd_dum_0    5.677960
# 6          SaleType_dum_0    5.515808
# 7       Exterior1st_dum_0    5.407443
# 8            TotRmsAbvGrd    5.335035
# 9     SaleCondition_dum_0    5.265761
# 10             GarageCars    5.208898
# 11     BsmtExposure_dum_2    4.895110
# 12            OverallQual    4.617005
# 13      Exterior1st_dum_2    4.614318
# 14                LotArea    4.366020
# 15      Exterior2nd_dum_2    4.197933
# 16              BsmtUnfSF    3.620833
# 17               2ndFlrSF    3.456970
# 18               FullBath    3.221103
# 19       Foundation_dum_0    3.164288
# 20           YearRemodAdd    3.094653
# 21       HouseStyle_dum_0    3.084639
# 22         BldgType_dum_0    3.021171
# 23           BedroomAbvGr    2.957169
# 24     GarageFinish_dum_1    2.945605
# 25       GarageCond_dum_2    2.701199
# 26           KitchenAbvGr    2.692280
# 27       GarageType_dum_0    2.642044
# 28     GarageFinish_dum_0    2.601652
# 29       Foundation_dum_1    2.585206
# ..                    ...         ...
# 124       Street_dum_Pave    1.299742
# 125           ScreenPorch    1.292321
# 126        SaleType_dum_2    1.281762
# 127     MiscFeature_dum_0    1.275244
# 128      Foundation_dum_2    1.274959
# 129         Heating_dum_2    1.245576
# 130      PavedDrive_dum_1    1.234209
# 131       HeatingQC_dum_2    1.202589
# 132  Utilities_dum_AllPub    1.200214
# 133       ExterCond_dum_2    1.194249
# 134       LotConfig_dum_2    1.184850
# 135     FireplaceQu_dum_2    1.178913
# 136                MoSold    1.157773
# 137       LotConfig_dum_0    1.157112
# 138             3SsnPorch    1.156705
# 139           Fence_dum_2    1.145518
# 140        SaleType_dum_3    1.125800
# 141            MasVnrArea    1.068393
# 142      Electrical_dum_2    1.056310
# 143      Condition1_dum_3    1.041260
# 144                YrSold    0.023795
# 145        LotShape_dum_2         NaN
# 146     LandContour_dum_2         NaN
# 147      Condition2_dum_3         NaN
# 148      HouseStyle_dum_3         NaN
# 149     Exterior2nd_dum_4         NaN
# 150       ExterQual_dum_2         NaN
# 151     KitchenQual_dum_2         NaN
# 152    GarageFinish_dum_2         NaN
# 153          PoolQC_dum_2         NaN
#
# [154 rows x 2 columns]
# GarageCond_dum_0 dropped
#                  features  vif factor
# 0                1stFlrSF    6.019050
# 1              BsmtFinSF1    5.998239
# 2              GarageArea    5.829322
# 3       Exterior2nd_dum_0    5.677760
# 4          SaleType_dum_0    5.512926
# 5       Exterior1st_dum_0    5.405214
# 6            TotRmsAbvGrd    5.333153
# 7     SaleCondition_dum_0    5.260635
# 8              GarageCars    5.208128
# 9      BsmtExposure_dum_2    4.894571
# 10            OverallQual    4.616831
# 11      Exterior1st_dum_2    4.613926
# 12                LotArea    4.362370
# 13      Exterior2nd_dum_2    4.190867
# 14       GarageQual_dum_0    3.907671
# 15              BsmtUnfSF    3.620207
# 16               2ndFlrSF    3.454906
# 17               FullBath    3.218308
# 18       Foundation_dum_0    3.155025
# 19           YearRemodAdd    3.089112
# 20       HouseStyle_dum_0    3.064078
# 21         BldgType_dum_0    2.999204
# 22           BedroomAbvGr    2.949172
# 23     GarageFinish_dum_1    2.794735
# 24           KitchenAbvGr    2.689787
# 25       GarageCond_dum_2    2.633861
# 26       GarageType_dum_0    2.594759
# 27       Foundation_dum_1    2.577576
# 28        ExterQual_dum_0    2.570303
# 29           BsmtFullBath    2.569665
# ..                    ...         ...
# 123       Street_dum_Pave    1.299441
# 124           ScreenPorch    1.291515
# 125        SaleType_dum_2    1.279843
# 126     MiscFeature_dum_0    1.274148
# 127      Foundation_dum_2    1.266917
# 128         Heating_dum_2    1.242919
# 129      PavedDrive_dum_1    1.229093
# 130       HeatingQC_dum_2    1.202369
# 131  Utilities_dum_AllPub    1.200002
# 132       ExterCond_dum_2    1.194245
# 133     FireplaceQu_dum_2    1.178907
# 134       LotConfig_dum_2    1.178643
# 135       LotConfig_dum_0    1.157094
# 136                MoSold    1.157038
# 137             3SsnPorch    1.152859
# 138           Fence_dum_2    1.144437
# 139        SaleType_dum_3    1.125799
# 140            MasVnrArea    1.068025
# 141      Electrical_dum_2    1.056021
# 142      Condition1_dum_3    1.041231
# 143                YrSold    0.023773
# 144        LotShape_dum_2         NaN
# 145     LandContour_dum_2         NaN
# 146      Condition2_dum_3         NaN
# 147      HouseStyle_dum_3         NaN
# 148     Exterior2nd_dum_4         NaN
# 149       ExterQual_dum_2         NaN
# 150     KitchenQual_dum_2         NaN
# 151    GarageFinish_dum_2         NaN
# 152          PoolQC_dum_2         NaN
#
# [153 rows x 2 columns]
# 1stFlrSF dropped
#                  features  vif factor
# 0              GarageArea    5.781251
# 1       Exterior2nd_dum_0    5.677055
# 2          SaleType_dum_0    5.495163
# 3       Exterior1st_dum_0    5.405173
# 4     SaleCondition_dum_0    5.242672
# 5              GarageCars    5.207712
# 6              BsmtFinSF1    5.061272
# 7      BsmtExposure_dum_2    4.883462
# 8            TotRmsAbvGrd    4.631816
# 9       Exterior1st_dum_2    4.570567
# 10            OverallQual    4.551331
# 11      Exterior2nd_dum_2    4.187791
# 12                LotArea    4.144981
# 13       GarageQual_dum_0    3.873973
# 14               2ndFlrSF    3.388375
# 15               FullBath    3.209958
# 16       Foundation_dum_0    3.154760
# 17           YearRemodAdd    3.082566
# 18         BldgType_dum_0    2.964619
# 19           BedroomAbvGr    2.947743
# 20              BsmtUnfSF    2.820248
# 21     GarageFinish_dum_1    2.793452
# 22       HouseStyle_dum_0    2.731689
# 23           KitchenAbvGr    2.689156
# 24       GarageCond_dum_2    2.631076
# 25       Foundation_dum_1    2.577556
# 26        ExterQual_dum_0    2.569745
# 27           BsmtFullBath    2.565810
# 28       GarageType_dum_0    2.544087
# 29       GarageQual_dum_2    2.535242
# ..                    ...         ...
# 122       Street_dum_Pave    1.296752
# 123           ScreenPorch    1.291370
# 124        SaleType_dum_2    1.278078
# 125     MiscFeature_dum_0    1.269742
# 126      Foundation_dum_2    1.266227
# 127         Heating_dum_2    1.242811
# 128      PavedDrive_dum_1    1.229092
# 129       HeatingQC_dum_2    1.200631
# 130  Utilities_dum_AllPub    1.199458
# 131       ExterCond_dum_2    1.190346
# 132     FireplaceQu_dum_2    1.178283
# 133       LotConfig_dum_2    1.178193
# 134       LotConfig_dum_0    1.157085
# 135                MoSold    1.151097
# 136             3SsnPorch    1.150261
# 137           Fence_dum_2    1.140110
# 138        SaleType_dum_3    1.125775
# 139            MasVnrArea    1.067851
# 140      Electrical_dum_2    1.055364
# 141      Condition1_dum_3    1.040702
# 142                YrSold    0.023767
# 143        LotShape_dum_2         NaN
# 144     LandContour_dum_2         NaN
# 145      Condition2_dum_3         NaN
# 146      HouseStyle_dum_3         NaN
# 147     Exterior2nd_dum_4         NaN
# 148       ExterQual_dum_2         NaN
# 149     KitchenQual_dum_2         NaN
# 150    GarageFinish_dum_2         NaN
# 151          PoolQC_dum_2         NaN
#
# [152 rows x 2 columns]
# GarageArea dropped
#                  features  vif factor
# 0       Exterior2nd_dum_0    5.676037
# 1          SaleType_dum_0    5.492677
# 2       Exterior1st_dum_0    5.403444
# 3     SaleCondition_dum_0    5.237076
# 4              BsmtFinSF1    4.986450
# 5      BsmtExposure_dum_2    4.875780
# 6            TotRmsAbvGrd    4.631598
# 7       Exterior1st_dum_2    4.568424
# 8             OverallQual    4.547115
# 9       Exterior2nd_dum_2    4.186871
# 10                LotArea    4.119858
# 11       GarageQual_dum_0    3.696508
# 12               2ndFlrSF    3.367397
# 13               FullBath    3.206860
# 14       Foundation_dum_0    3.152158
# 15           YearRemodAdd    3.082523
# 16         BldgType_dum_0    2.962947
# 17           BedroomAbvGr    2.928165
# 18              BsmtUnfSF    2.804985
# 19     GarageFinish_dum_1    2.770692
# 20       HouseStyle_dum_0    2.731563
# 21           KitchenAbvGr    2.689133
# 22       GarageCond_dum_2    2.630972
# 23             GarageCars    2.593615
# 24       Foundation_dum_1    2.576978
# 25        ExterQual_dum_0    2.567747
# 26           BsmtFullBath    2.565607
# 27       GarageType_dum_0    2.542112
# 28       GarageQual_dum_2    2.507865
# 29           PoolQC_dum_1    2.502041
# ..                    ...         ...
# 121       Street_dum_Pave    1.296739
# 122           ScreenPorch    1.291061
# 123        SaleType_dum_2    1.276799
# 124     MiscFeature_dum_0    1.269121
# 125      Foundation_dum_2    1.266190
# 126         Heating_dum_2    1.242395
# 127      PavedDrive_dum_1    1.226567
# 128       HeatingQC_dum_2    1.199487
# 129  Utilities_dum_AllPub    1.199457
# 130       ExterCond_dum_2    1.190225
# 131       LotConfig_dum_2    1.178188
# 132     FireplaceQu_dum_2    1.171253
# 133       LotConfig_dum_0    1.156363
# 134                MoSold    1.150002
# 135             3SsnPorch    1.148022
# 136           Fence_dum_2    1.139928
# 137        SaleType_dum_3    1.125641
# 138            MasVnrArea    1.067835
# 139      Electrical_dum_2    1.055354
# 140      Condition1_dum_3    1.040702
# 141                YrSold    0.023767
# 142        LotShape_dum_2         NaN
# 143     LandContour_dum_2         NaN
# 144      Condition2_dum_3         NaN
# 145      HouseStyle_dum_3         NaN
# 146     Exterior2nd_dum_4         NaN
# 147       ExterQual_dum_2         NaN
# 148     KitchenQual_dum_2         NaN
# 149    GarageFinish_dum_2         NaN
# 150          PoolQC_dum_2         NaN
#
# [151 rows x 2 columns]
# Exterior2nd_dum_0 dropped
#                  features  vif factor
# 0          SaleType_dum_0    5.490784
# 1     SaleCondition_dum_0    5.236363
# 2              BsmtFinSF1    4.984097
# 3      BsmtExposure_dum_2    4.862170
# 4            TotRmsAbvGrd    4.628023
# 5             OverallQual    4.542419
# 6                 LotArea    4.118133
# 7        GarageQual_dum_0    3.695688
# 8                2ndFlrSF    3.367308
# 9                FullBath    3.205484
# 10       Foundation_dum_0    3.150519
# 11           YearRemodAdd    3.082295
# 12      Exterior1st_dum_2    3.050022
# 13         BldgType_dum_0    2.962848
# 14           BedroomAbvGr    2.924693
# 15              BsmtUnfSF    2.799739
# 16      Exterior2nd_dum_2    2.795939
# 17     GarageFinish_dum_1    2.770585
# 18       HouseStyle_dum_0    2.730927
# 19           KitchenAbvGr    2.683146
# 20       GarageCond_dum_2    2.621352
# 21             GarageCars    2.593115
# 22       Foundation_dum_1    2.571316
# 23        ExterQual_dum_0    2.567573
# 24           BsmtFullBath    2.564285
# 25       GarageType_dum_0    2.537101
# 26       GarageQual_dum_2    2.506089
# 27           PoolQC_dum_1    2.501835
# 28         BldgType_dum_1    2.476190
# 29       GarageType_dum_1    2.439386
# ..                    ...         ...
# 120       Street_dum_Pave    1.296523
# 121           ScreenPorch    1.290526
# 122        SaleType_dum_2    1.276763
# 123     MiscFeature_dum_0    1.269028
# 124      Foundation_dum_2    1.266119
# 125         Heating_dum_2    1.233596
# 126      PavedDrive_dum_1    1.226549
# 127       HeatingQC_dum_2    1.199327
# 128  Utilities_dum_AllPub    1.199009
# 129       ExterCond_dum_2    1.188452
# 130       LotConfig_dum_2    1.178184
# 131     FireplaceQu_dum_2    1.170753
# 132       LotConfig_dum_0    1.156311
# 133                MoSold    1.149951
# 134             3SsnPorch    1.148016
# 135           Fence_dum_2    1.130516
# 136        SaleType_dum_3    1.125284
# 137            MasVnrArea    1.067830
# 138      Electrical_dum_2    1.055353
# 139      Condition1_dum_3    1.040407
# 140                YrSold    0.023765
# 141        LotShape_dum_2         NaN
# 142     LandContour_dum_2         NaN
# 143      Condition2_dum_3         NaN
# 144      HouseStyle_dum_3         NaN
# 145     Exterior2nd_dum_4         NaN
# 146       ExterQual_dum_2         NaN
# 147     KitchenQual_dum_2         NaN
# 148    GarageFinish_dum_2         NaN
# 149          PoolQC_dum_2         NaN
#
# [150 rows x 2 columns]
# SaleType_dum_0 dropped
#                  features  vif factor
# 0              BsmtFinSF1    4.981235
# 1      BsmtExposure_dum_2    4.862136
# 2            TotRmsAbvGrd    4.627944
# 3             OverallQual    4.542380
# 4                 LotArea    4.118133
# 5        GarageQual_dum_0    3.691048
# 6                2ndFlrSF    3.365613
# 7                FullBath    3.203965
# 8        Foundation_dum_0    3.150147
# 9            YearRemodAdd    3.061798
# 10      Exterior1st_dum_2    3.047943
# 11         BldgType_dum_0    2.962215
# 12           BedroomAbvGr    2.913164
# 13              BsmtUnfSF    2.799648
# 14      Exterior2nd_dum_2    2.795924
# 15     GarageFinish_dum_1    2.769983
# 16       HouseStyle_dum_0    2.721616
# 17           KitchenAbvGr    2.683136
# 18       GarageCond_dum_2    2.618640
# 19             GarageCars    2.592416
# 20       Foundation_dum_1    2.571123
# 21        ExterQual_dum_0    2.567351
# 22           BsmtFullBath    2.564285
# 23       GarageType_dum_0    2.533809
# 24       GarageQual_dum_2    2.504775
# 25           PoolQC_dum_1    2.499743
# 26         BldgType_dum_1    2.460802
# 27       GarageType_dum_1    2.439364
# 28         RoofMatl_dum_0    2.419808
# 29     GarageFinish_dum_0    2.408046
# ..                    ...         ...
# 119       Street_dum_Pave    1.295612
# 120           ScreenPorch    1.290396
# 121     MiscFeature_dum_0    1.268607
# 122      Foundation_dum_2    1.266075
# 123         Heating_dum_2    1.233560
# 124      PavedDrive_dum_1    1.226532
# 125       HeatingQC_dum_2    1.199327
# 126  Utilities_dum_AllPub    1.198986
# 127        SaleType_dum_2    1.194342
# 128       ExterCond_dum_2    1.188424
# 129       LotConfig_dum_2    1.176077
# 130     FireplaceQu_dum_2    1.170100
# 131       LotConfig_dum_0    1.153387
# 132                MoSold    1.149157
# 133             3SsnPorch    1.147878
# 134           Fence_dum_2    1.130414
# 135        SaleType_dum_3    1.118811
# 136            MasVnrArea    1.067733
# 137      Electrical_dum_2    1.055289
# 138      Condition1_dum_3    1.040351
# 139                YrSold    0.023716
# 140        LotShape_dum_2         NaN
# 141     LandContour_dum_2         NaN
# 142      Condition2_dum_3         NaN
# 143      HouseStyle_dum_3         NaN
# 144     Exterior2nd_dum_4         NaN
# 145       ExterQual_dum_2         NaN
# 146     KitchenQual_dum_2         NaN
# 147    GarageFinish_dum_2         NaN
# 148          PoolQC_dum_2         NaN
#
# [149 rows x 2 columns]
# BsmtFinSF1 dropped
#                  features  vif factor
# 0      BsmtExposure_dum_2    4.837522
# 1            TotRmsAbvGrd    4.627662
# 2             OverallQual    4.383747
# 3                 LotArea    4.012818
# 4        GarageQual_dum_0    3.689335
# 5                2ndFlrSF    3.341692
# 6                FullBath    3.163554
# 7        Foundation_dum_0    3.148290
# 8            YearRemodAdd    3.061777
# 9       Exterior1st_dum_2    3.009385
# 10         BldgType_dum_0    2.961508
# 11           BedroomAbvGr    2.908989
# 12      Exterior2nd_dum_2    2.792353
# 13     GarageFinish_dum_1    2.760869
# 14           KitchenAbvGr    2.682037
# 15       GarageCond_dum_2    2.613140
# 16       HouseStyle_dum_0    2.588366
# 17       Foundation_dum_1    2.568970
# 18             GarageCars    2.566811
# 19        ExterQual_dum_0    2.566792
# 20       GarageType_dum_0    2.527547
# 21       GarageQual_dum_2    2.504628
# 22           PoolQC_dum_1    2.489206
# 23         BldgType_dum_1    2.442294
# 24       GarageType_dum_1    2.431236
# 25         RoofMatl_dum_0    2.419635
# 26     GarageFinish_dum_0    2.399825
# 27        HeatingQC_dum_0    2.311145
# 28         BsmtCond_dum_1    2.296398
# 29               HalfBath    2.292494
# ..                    ...         ...
# 118       Street_dum_Pave    1.295318
# 119           ScreenPorch    1.289394
# 120     MiscFeature_dum_0    1.267009
# 121      Foundation_dum_2    1.263557
# 122         Heating_dum_2    1.233508
# 123      PavedDrive_dum_1    1.224037
# 124  Utilities_dum_AllPub    1.198720
# 125       HeatingQC_dum_2    1.198252
# 126        SaleType_dum_2    1.193845
# 127       ExterCond_dum_2    1.188340
# 128       LotConfig_dum_2    1.175984
# 129     FireplaceQu_dum_2    1.164306
# 130       LotConfig_dum_0    1.152912
# 131                MoSold    1.148805
# 132             3SsnPorch    1.146031
# 133           Fence_dum_2    1.129110
# 134        SaleType_dum_3    1.117157
# 135            MasVnrArea    1.066909
# 136      Electrical_dum_2    1.055288
# 137      Condition1_dum_3    1.040308
# 138                YrSold    0.023531
# 139        LotShape_dum_2         NaN
# 140     LandContour_dum_2         NaN
# 141      Condition2_dum_3         NaN
# 142      HouseStyle_dum_3         NaN
# 143     Exterior2nd_dum_4         NaN
# 144       ExterQual_dum_2         NaN
# 145     KitchenQual_dum_2         NaN
# 146    GarageFinish_dum_2         NaN
# 147          PoolQC_dum_2         NaN
#
# [148 rows x 2 columns]
# BsmtExposure_dum_2 dropped
#                  features  vif factor
# 0            TotRmsAbvGrd    4.627554
# 1             OverallQual    4.381988
# 2                 LotArea    4.012670
# 3        GarageQual_dum_0    3.688927
# 4                2ndFlrSF    3.337943
# 5                FullBath    3.161865
# 6        Foundation_dum_0    3.133689
# 7            YearRemodAdd    3.059745
# 8       Exterior1st_dum_2    3.008986
# 9          BldgType_dum_0    2.961478
# 10           BedroomAbvGr    2.894837
# 11      Exterior2nd_dum_2    2.792245
# 12     GarageFinish_dum_1    2.760804
# 13           KitchenAbvGr    2.660267
# 14       GarageCond_dum_2    2.596502
# 15       HouseStyle_dum_0    2.586573
# 16             GarageCars    2.566411
# 17        ExterQual_dum_0    2.560553
# 18       GarageType_dum_0    2.524295
# 19       GarageQual_dum_2    2.503181
# 20       Foundation_dum_1    2.493935
# 21           PoolQC_dum_1    2.488971
# 22         BldgType_dum_1    2.437833
# 23       GarageType_dum_1    2.428299
# 24         RoofMatl_dum_0    2.416692
# 25     GarageFinish_dum_0    2.398672
# 26               HalfBath    2.290332
# 27        HeatingQC_dum_0    2.286807
# 28       CentralAir_dum_Y    2.286464
# 29         BsmtQual_dum_0    2.174176
# ..                    ...         ...
# 117           ScreenPorch    1.289392
# 118          BsmtHalfBath    1.288118
# 119     MiscFeature_dum_0    1.265152
# 120      Foundation_dum_2    1.263522
# 121         Heating_dum_2    1.230792
# 122      PavedDrive_dum_1    1.221393
# 123       HeatingQC_dum_2    1.198204
# 124  Utilities_dum_AllPub    1.198150
# 125        SaleType_dum_2    1.189409
# 126       ExterCond_dum_2    1.188338
# 127       LotConfig_dum_2    1.175830
# 128     FireplaceQu_dum_2    1.161839
# 129       LotConfig_dum_0    1.152609
# 130                MoSold    1.146880
# 131             3SsnPorch    1.144305
# 132           Fence_dum_2    1.126397
# 133        SaleType_dum_3    1.117110
# 134            MasVnrArea    1.066722
# 135      Electrical_dum_2    1.055287
# 136      Condition1_dum_3    1.040308
# 137                YrSold    0.023513
# 138        LotShape_dum_2         NaN
# 139     LandContour_dum_2         NaN
# 140      Condition2_dum_3         NaN
# 141      HouseStyle_dum_3         NaN
# 142     Exterior2nd_dum_4         NaN
# 143       ExterQual_dum_2         NaN
# 144     KitchenQual_dum_2         NaN
# 145    GarageFinish_dum_2         NaN
# 146          PoolQC_dum_2         NaN
#
# [147 rows x 2 columns]
# TotRmsAbvGrd dropped
#                  features  vif factor
# 0             OverallQual    4.257601
# 1                 LotArea    3.978582
# 2        GarageQual_dum_0    3.688071
# 3                2ndFlrSF    3.177676
# 4        Foundation_dum_0    3.121756
# 5                FullBath    3.116369
# 6            YearRemodAdd    3.044658
# 7       Exterior1st_dum_2    3.008972
# 8          BldgType_dum_0    2.926902
# 9       Exterior2nd_dum_2    2.789650
# 10     GarageFinish_dum_1    2.756115
# 11       GarageCond_dum_2    2.594385
# 12             GarageCars    2.560521
# 13        ExterQual_dum_0    2.559301
# 14       HouseStyle_dum_0    2.548224
# 15       GarageType_dum_0    2.524278
# 16       GarageQual_dum_2    2.500813
# 17           KitchenAbvGr    2.492421
# 18       Foundation_dum_1    2.491564
# 19           PoolQC_dum_1    2.484875
# 20         BldgType_dum_1    2.437271
# 21       GarageType_dum_1    2.417405
# 22         RoofMatl_dum_0    2.416406
# 23     GarageFinish_dum_0    2.398411
# 24        HeatingQC_dum_0    2.286579
# 25       CentralAir_dum_Y    2.286434
# 26               HalfBath    2.269828
# 27         BsmtQual_dum_0    2.172863
# 28           BedroomAbvGr    2.167230
# 29         MSZoning_dum_0    2.125423
# ..                    ...         ...
# 116           ScreenPorch    1.288860
# 117          BsmtHalfBath    1.285395
# 118     MiscFeature_dum_0    1.265099
# 119      Foundation_dum_2    1.262635
# 120         Heating_dum_2    1.230758
# 121      PavedDrive_dum_1    1.221233
# 122       HeatingQC_dum_2    1.198203
# 123  Utilities_dum_AllPub    1.197896
# 124        SaleType_dum_2    1.187924
# 125       ExterCond_dum_2    1.187454
# 126       LotConfig_dum_2    1.175402
# 127     FireplaceQu_dum_2    1.161555
# 128       LotConfig_dum_0    1.147483
# 129                MoSold    1.146155
# 130             3SsnPorch    1.144232
# 131           Fence_dum_2    1.126303
# 132        SaleType_dum_3    1.117110
# 133            MasVnrArea    1.066241
# 134      Electrical_dum_2    1.055215
# 135      Condition1_dum_3    1.040232
# 136                YrSold    0.023493
# ...
# 20               HalfBath    2.246081
# 21         BsmtQual_dum_0    2.169956
# 22           BedroomAbvGr    2.131385
# 23     GarageFinish_dum_1    2.113971
# 24       GarageType_dum_1    2.108376
# 25           PoolQC_dum_0    2.099664
# 26     BsmtFinType1_dum_1    2.073788
# 27     BsmtFinType1_dum_2    2.065991
# 28      KitchenQual_dum_0    2.034470
# 29              BsmtUnfSF    2.027649
# ..                    ...         ...
# 113          BsmtHalfBath    1.282394
# 114       Street_dum_Pave    1.276957
# 115      Foundation_dum_2    1.257505
# 116     MiscFeature_dum_0    1.254258
# 117         Heating_dum_2    1.219608
# 118      PavedDrive_dum_1    1.205429
# 119       HeatingQC_dum_2    1.198149
# 120  Utilities_dum_AllPub    1.197229
# 121        SaleType_dum_2    1.178692
# 122       ExterCond_dum_2    1.173222
# 123       LotConfig_dum_2    1.170555
# 124     FireplaceQu_dum_2    1.145767
# 125       LotConfig_dum_0    1.144563
# 126                MoSold    1.143336
# 127             3SsnPorch    1.141752
# 128           Fence_dum_2    1.121302
# 129        SaleType_dum_3    1.112055
# 130            MasVnrArea    1.065155
# 131      Electrical_dum_2    1.049739
# 132      Condition1_dum_3    1.038275
# 133                YrSold    0.018238
# 134        LotShape_dum_2         NaN
# 135     LandContour_dum_2         NaN
# 136      Condition2_dum_3         NaN
# 137      HouseStyle_dum_3         NaN
# 138     Exterior2nd_dum_4         NaN
# 139       ExterQual_dum_2         NaN
# 140     KitchenQual_dum_2         NaN
# 141    GarageFinish_dum_2         NaN
# 142          PoolQC_dum_2         NaN
#
# [143 rows x 2 columns]
# 2ndFlrSF dropped
#                  features  vif factor
# 0        Foundation_dum_0    3.055966
# 1            YearRemodAdd    3.005551
# 2       Exterior1st_dum_2    3.001008
# 3       Exterior2nd_dum_2    2.787317
# 4                FullBath    2.707436
# 5        GarageCond_dum_2    2.538037
# 6            KitchenAbvGr    2.477081
# 7        Foundation_dum_1    2.459324
# 8         ExterQual_dum_0    2.446346
# 9            PoolQC_dum_1    2.407006
# 10         RoofMatl_dum_0    2.406486
# 11       HouseStyle_dum_0    2.392826
# 12       GarageQual_dum_2    2.384483
# 13         BldgType_dum_1    2.337075
# 14       GarageType_dum_0    2.298531
# 15             GarageCars    2.295033
# 16         BldgType_dum_0    2.290900
# 17       CentralAir_dum_Y    2.266654
# 18        HeatingQC_dum_0    2.264051
# 19         BsmtQual_dum_0    2.163790
# 20               HalfBath    2.117645
# 21     GarageFinish_dum_1    2.077505
# 22     BsmtFinType1_dum_1    2.072541
# 23     BsmtFinType1_dum_2    2.064464
# 24      KitchenQual_dum_0    2.034129
# 25      Exterior1st_dum_3    2.020885
# 26              BsmtUnfSF    1.996000
# 27      Exterior1st_dum_1    1.982574
# 28            OverallCond    1.965432
# 29           BedroomAbvGr    1.958686
# ..                    ...         ...
# 112       Street_dum_Pave    1.276925
# 113          BsmtHalfBath    1.276375
# 114     MiscFeature_dum_0    1.254183
# 115      Foundation_dum_2    1.245822
# 116         Heating_dum_2    1.215949
# 117      PavedDrive_dum_1    1.204701
# 118       HeatingQC_dum_2    1.196895
# 119  Utilities_dum_AllPub    1.196886
# 120        SaleType_dum_2    1.178687
# 121       ExterCond_dum_2    1.173110
# 122       LotConfig_dum_2    1.167278
# 123     FireplaceQu_dum_2    1.143819
# 124       LotConfig_dum_0    1.143645
# 125                MoSold    1.142906
# 126             3SsnPorch    1.141009
# 127           Fence_dum_2    1.120783
# 128        SaleType_dum_3    1.112015
# 129            MasVnrArea    1.064901
# 130      Electrical_dum_2    1.046868
# 131      Condition1_dum_3    1.037944
# 132                YrSold    0.018217
# 133        LotShape_dum_2         NaN
# 134     LandContour_dum_2         NaN
# 135      Condition2_dum_3         NaN
# 136      HouseStyle_dum_3         NaN
# 137     Exterior2nd_dum_4         NaN
# 138       ExterQual_dum_2         NaN
# 139     KitchenQual_dum_2         NaN
# 140    GarageFinish_dum_2         NaN
# 141          PoolQC_dum_2         NaN
#
# [142 rows x 2 columns]
# Foundation_dum_0 dropped
#                  features  vif factor
# 0       Exterior1st_dum_2    3.000828
# 1            YearRemodAdd    2.966231
# 2       Exterior2nd_dum_2    2.776344
# 3                FullBath    2.705234
# 4        GarageCond_dum_2    2.537279
# 5            KitchenAbvGr    2.477081
# 6         ExterQual_dum_0    2.435707
# 7            PoolQC_dum_1    2.405187
# 8          RoofMatl_dum_0    2.405140
# 9        GarageQual_dum_2    2.383098
# 10       HouseStyle_dum_0    2.380077
# 11         BldgType_dum_1    2.312528
# 12       GarageType_dum_0    2.291449
# 13         BldgType_dum_0    2.288517
# 14             GarageCars    2.288016
# 15       CentralAir_dum_Y    2.265431
# 16        HeatingQC_dum_0    2.192244
# 17         BsmtQual_dum_0    2.117181
# 18               HalfBath    2.117074
# 19     GarageFinish_dum_1    2.072972
# 20      KitchenQual_dum_0    2.004962
# 21      Exterior1st_dum_3    1.997674
# 22              BsmtUnfSF    1.995852
# 23     BsmtFinType1_dum_1    1.990488
# 24     BsmtFinType1_dum_2    1.986106
# 25       Foundation_dum_1    1.985137
# 26      Exterior1st_dum_1    1.977370
# 27           BedroomAbvGr    1.956495
# 28       Condition2_dum_0    1.953523
# 29         BsmtCond_dum_1    1.920621
# ..                    ...         ...
# 111       Street_dum_Pave    1.275078
# 112          BsmtHalfBath    1.272475
# 113     MiscFeature_dum_0    1.253255
# 114      Foundation_dum_2    1.245779
# 115         Heating_dum_2    1.214889
# 116      PavedDrive_dum_1    1.202096
# 117  Utilities_dum_AllPub    1.196776
# 118       HeatingQC_dum_2    1.196019
# 119        SaleType_dum_2    1.176028
# 120       ExterCond_dum_2    1.169863
# 121       LotConfig_dum_2    1.167170
# 122     FireplaceQu_dum_2    1.143815
# 123                MoSold    1.141887
# 124       LotConfig_dum_0    1.141535
# 125             3SsnPorch    1.140724
# 126           Fence_dum_2    1.120778
# 127        SaleType_dum_3    1.111490
# 128            MasVnrArea    1.064855
# 129      Electrical_dum_2    1.046585
# 130      Condition1_dum_3    1.037928
# 131                YrSold    0.017966
# 132        LotShape_dum_2         NaN
# 133     LandContour_dum_2         NaN
# 134      Condition2_dum_3         NaN
# 135      HouseStyle_dum_3         NaN
# 136     Exterior2nd_dum_4         NaN
# 137       ExterQual_dum_2         NaN
# 138     KitchenQual_dum_2         NaN
# 139    GarageFinish_dum_2         NaN
# 140          PoolQC_dum_2         NaN
#
# [141 rows x 2 columns]
# Exterior1st_dum_2 dropped
#                  features  vif factor
# 0            YearRemodAdd    2.949077
# 1                FullBath    2.688644
# 2        GarageCond_dum_2    2.537180
# 3            KitchenAbvGr    2.474748
# 4         ExterQual_dum_0    2.435433
# 5            PoolQC_dum_1    2.404292
# 6          RoofMatl_dum_0    2.402106
# 7        GarageQual_dum_2    2.381720
# 8        HouseStyle_dum_0    2.375780
# 9          BldgType_dum_1    2.312280
# 10       GarageType_dum_0    2.290136
# 11             GarageCars    2.285561
# 12         BldgType_dum_0    2.276927
# 13       CentralAir_dum_Y    2.253977
# 14        HeatingQC_dum_0    2.178678
# 15         BsmtQual_dum_0    2.116115
# 16               HalfBath    2.113486
# 17     GarageFinish_dum_1    2.067375
# 18      KitchenQual_dum_0    2.001712
# 19              BsmtUnfSF    1.994841
# 20     BsmtFinType1_dum_1    1.989886
# 21       Foundation_dum_1    1.985134
# 22      Exterior1st_dum_1    1.976670
# 23     BsmtFinType1_dum_2    1.973344
# 24           BedroomAbvGr    1.955867
# 25       Condition2_dum_0    1.928501
# 26         BsmtCond_dum_1    1.915883
# 27         MSZoning_dum_0    1.905883
# 28        RoofStyle_dum_1    1.902505
# 29        ExterQual_dum_1    1.884352
# ..                    ...         ...
# 110       Street_dum_Pave    1.275073
# 111          BsmtHalfBath    1.272421
# 112     MiscFeature_dum_0    1.253073
# 113      Foundation_dum_2    1.243102
# 114         Heating_dum_2    1.214848
# 115      PavedDrive_dum_1    1.201951
# 116  Utilities_dum_AllPub    1.196735
# 117       HeatingQC_dum_2    1.195688
# 118        SaleType_dum_2    1.175911
# 119       LotConfig_dum_2    1.165977
# 120       ExterCond_dum_2    1.165066
# 121     FireplaceQu_dum_2    1.142408
# 122       LotConfig_dum_0    1.141533
# 123                MoSold    1.141187
# 124             3SsnPorch    1.139630
# 125           Fence_dum_2    1.120750
# 126        SaleType_dum_3    1.111045
# 127            MasVnrArea    1.063923
# 128      Electrical_dum_2    1.046539
# 129      Condition1_dum_3    1.036796
# 130                YrSold    0.017924
# 131        LotShape_dum_2         NaN
# 132     LandContour_dum_2         NaN
# 133      Condition2_dum_3         NaN
# 134      HouseStyle_dum_3         NaN
# 135     Exterior2nd_dum_4         NaN
# 136       ExterQual_dum_2         NaN
# 137     KitchenQual_dum_2         NaN
# 138    GarageFinish_dum_2         NaN
# 139          PoolQC_dum_2         NaN
#
# [140 rows x 2 columns]
# YearRemodAdd dropped
#                  features  vif factor
# 0                FullBath    2.654700
# 1        GarageCond_dum_2    2.536325
# 2            KitchenAbvGr    2.474736
# 3         ExterQual_dum_0    2.424038
# 4            PoolQC_dum_1    2.404204
# 5          RoofMatl_dum_0    2.399742
# 6        GarageQual_dum_2    2.372660
# 7        HouseStyle_dum_0    2.372606
# 8          BldgType_dum_1    2.311993
# 9        GarageType_dum_0    2.290133
# 10         BldgType_dum_0    2.269719
# 11             GarageCars    2.266552
# 12       CentralAir_dum_Y    2.244529
# 13         BsmtQual_dum_0    2.115556
# 14               HalfBath    2.105902
# 15        HeatingQC_dum_0    2.094017
# 16     GarageFinish_dum_1    2.045146
# 17              BsmtUnfSF    1.992449
# 18       Foundation_dum_1    1.983360
# 19     BsmtFinType1_dum_1    1.966036
# 20      KitchenQual_dum_0    1.949321
# 21           BedroomAbvGr    1.940171
# 22      Exterior1st_dum_1    1.931498
# 23       Condition2_dum_0    1.925453
# 24     BsmtFinType1_dum_2    1.924582
# 25         MSZoning_dum_0    1.905262
# 26        RoofStyle_dum_1    1.902472
# 27         BsmtCond_dum_1    1.889309
# 28        ExterQual_dum_1    1.883972
# 29       Condition2_dum_1    1.876931
# ..                    ...         ...
# 109       Street_dum_Pave    1.274107
# 110          BsmtHalfBath    1.270666
# 111     MiscFeature_dum_0    1.252042
# 112      Foundation_dum_2    1.242409
# 113         Heating_dum_2    1.213943
# 114      PavedDrive_dum_1    1.198088
# 115       HeatingQC_dum_2    1.195037
# 116  Utilities_dum_AllPub    1.194677
# 117        SaleType_dum_2    1.175613
# 118       LotConfig_dum_2    1.165974
# 119       ExterCond_dum_2    1.161714
# 120     FireplaceQu_dum_2    1.142294
# 121       LotConfig_dum_0    1.141312
# 122                MoSold    1.141167
# 123             3SsnPorch    1.139625
# 124           Fence_dum_2    1.119811
# 125        SaleType_dum_3    1.110772
# 126            MasVnrArea    1.063808
# 127      Electrical_dum_2    1.045558
# 128      Condition1_dum_3    1.036682
# 129                YrSold    0.007418
# 130        LotShape_dum_2         NaN
# 131     LandContour_dum_2         NaN
# 132      Condition2_dum_3         NaN
# 133      HouseStyle_dum_3         NaN
# 134     Exterior2nd_dum_4         NaN
# 135       ExterQual_dum_2         NaN
# 136     KitchenQual_dum_2         NaN
# 137    GarageFinish_dum_2         NaN
# 138          PoolQC_dum_2         NaN
#
# [139 rows x 2 columns]
# FullBath dropped
#                  features  vif factor
# 0        GarageCond_dum_2    2.534852
# 1         ExterQual_dum_0    2.423953
# 2            KitchenAbvGr    2.411462
# 3          RoofMatl_dum_0    2.390101
# 4            PoolQC_dum_1    2.385887
# 5        GarageQual_dum_2    2.371236
# 6        HouseStyle_dum_0    2.315427
# 7          BldgType_dum_1    2.306791
# 8          BldgType_dum_0    2.269465
# 9        GarageType_dum_0    2.259273
# 10       CentralAir_dum_Y    2.244518
# 11             GarageCars    2.217054
# 12        HeatingQC_dum_0    2.083310
# 13         BsmtQual_dum_0    2.073228
# 14     GarageFinish_dum_1    2.044275
# 15               HalfBath    2.014582
# 16              BsmtUnfSF    1.992372
# 17       Foundation_dum_1    1.974320
# 18     BsmtFinType1_dum_1    1.958514
# 19      Exterior1st_dum_1    1.930978
# 20     BsmtFinType1_dum_2    1.924365
# 21       Condition2_dum_0    1.918044
# 22      KitchenQual_dum_0    1.911111
# 23        RoofStyle_dum_1    1.895235
# 24         BsmtCond_dum_1    1.889309
# 25         MSZoning_dum_0    1.880645
# 26        ExterQual_dum_1    1.877341
# 27       GarageType_dum_1    1.867318
# 28       Condition2_dum_1    1.863904
# 29           PoolQC_dum_0    1.837872
# ..                    ...         ...
# 108       Street_dum_Pave    1.271774
# 109          BsmtHalfBath    1.262995
# 110     MiscFeature_dum_0    1.251957
# 111      Foundation_dum_2    1.241022
# 112         Heating_dum_2    1.212935
# 113      PavedDrive_dum_1    1.197826
# 114       HeatingQC_dum_2    1.194641
# 115  Utilities_dum_AllPub    1.190164
# 116        SaleType_dum_2    1.173457
# 117       LotConfig_dum_2    1.163775
# 118       ExterCond_dum_2    1.159417
# 119     FireplaceQu_dum_2    1.142042
# 120                MoSold    1.141150
# 121       LotConfig_dum_0    1.140353
# 122             3SsnPorch    1.138437
# 123           Fence_dum_2    1.119690
# 124        SaleType_dum_3    1.110723
# 125            MasVnrArea    1.063693
# 126      Electrical_dum_2    1.045535
# 127      Condition1_dum_3    1.036605
# 128                YrSold    0.007393
# 129        LotShape_dum_2         NaN
# 130     LandContour_dum_2         NaN
# 131      Condition2_dum_3         NaN
# 132      HouseStyle_dum_3         NaN
# 133     Exterior2nd_dum_4         NaN
# 134       ExterQual_dum_2         NaN
# 135     KitchenQual_dum_2         NaN
# 136    GarageFinish_dum_2         NaN
# 137          PoolQC_dum_2         NaN
#
# [138 rows x 2 columns]
# GarageCond_dum_2 dropped
#                  features  vif factor
# 0         ExterQual_dum_0    2.421751
# 1            PoolQC_dum_1    2.381609
# 2          RoofMatl_dum_0    2.366112
# 3            KitchenAbvGr    2.313174
# 4        HouseStyle_dum_0    2.299679
# 5          BldgType_dum_1    2.269128
# 6          BldgType_dum_0    2.268961
# 7        GarageType_dum_0    2.258168
# 8        CentralAir_dum_Y    2.243530
# 9              GarageCars    2.210016
# 10        HeatingQC_dum_0    2.080838
# 11         BsmtQual_dum_0    2.068352
# 12     GarageFinish_dum_1    2.042113
# 13               HalfBath    2.012913
# 14              BsmtUnfSF    1.992169
# 15       Foundation_dum_1    1.968693
# 16     BsmtFinType1_dum_1    1.958272
# 17      Exterior1st_dum_1    1.925108
# 18     BsmtFinType1_dum_2    1.924164
# 19       Condition2_dum_0    1.914783
# 20      KitchenQual_dum_0    1.909207
# 21        RoofStyle_dum_1    1.888981
# 22         BsmtCond_dum_1    1.886429
# 23        ExterQual_dum_1    1.876740
# 24         MSZoning_dum_0    1.876438
# 25       GarageType_dum_1    1.865672
# 26       Condition2_dum_1    1.857309
# 27           PoolQC_dum_0    1.835769
# 28           BsmtFullBath    1.828400
# 29        LandSlope_dum_1    1.805659
# ..                    ...         ...
# 107          BsmtHalfBath    1.262995
# 108     MiscFeature_dum_0    1.251427
# 109      Foundation_dum_2    1.239508
# 110      GarageQual_dum_2    1.227467
# 111         Heating_dum_2    1.212855
# 112       HeatingQC_dum_2    1.194369
# 113      PavedDrive_dum_1    1.190830
# 114  Utilities_dum_AllPub    1.190128
# 115        SaleType_dum_2    1.173053
# 116       LotConfig_dum_2    1.163775
# 117       ExterCond_dum_2    1.159158
# 118     FireplaceQu_dum_2    1.141517
# 119                MoSold    1.140070
# 120             3SsnPorch    1.137990
# 121       LotConfig_dum_0    1.134193
# 122           Fence_dum_2    1.119685
# 123        SaleType_dum_3    1.110489
# 124            MasVnrArea    1.063693
# 125      Electrical_dum_2    1.045534
# 126      Condition1_dum_3    1.036575
# 127                YrSold    0.007392
# 128        LotShape_dum_2         NaN
# 129     LandContour_dum_2         NaN
# 130      Condition2_dum_3         NaN
# 131      HouseStyle_dum_3         NaN
# 132     Exterior2nd_dum_4         NaN
# 133       ExterQual_dum_2         NaN
# 134     KitchenQual_dum_2         NaN
# 135    GarageFinish_dum_2         NaN
# 136          PoolQC_dum_2         NaN
#
# [137 rows x 2 columns]

# %%
len(vif_drop_cols)
# Out:
# 28

# %%
os.chdir('../Statistics')

# %%
edd = pd.read_csv('edd_v03.csv',header=0)

# %%
edd.loc[edd['Var'].isin(vif_drop_cols),'Status']='drop'

# %%
edd['Reason']=''
edd.loc[edd['Var'].isin(vif_drop_cols),'Reason']='VIF'

# %%
edd.to_csv('edd_v04.csv',index=False)

# %%
df.drop(vif_drop_cols,axis=1,inplace=True)

# %%
os.chdir('../output_data')

# %%
df.to_csv('train_v04.csv')

# %% [markdown]
# # BackWard Selection

# %%
import statsmodels.discrete.discrete_model as sm
from sklearn.preprocessing import StandardScaler

# %%
import statsmodels.api as sm

# %%
flag=0
cols_dropped=['SalePrice']
while flag==0:
    model = sm.OLS(endog=np.array(df['SalePrice']),exog=np.array(df.drop(cols_dropped,axis=1)))
    results = model.fit()
    pvalues=list(results.pvalues)
    drop_index = pvalues.index(max(pvalues))
    col_drop = df.drop(cols_dropped,axis=1).columns[drop_index]
    print(col_drop+'-'+str(pvalues[drop_index]))
    if pvalues[drop_index]>.05:
        cols_dropped.append(col_drop)
    else:
        flag=1
# Out:
# MasVnrArea-0.981068975796
# BsmtFinType2_dum_0-0.968705684371
# Foundation_dum_2-0.965571710815
# HouseStyle_dum_2-0.959763391492
# Neighborhood_dum_1-0.934779860187
# GarageType_dum_1-0.920425466991
# LotConfig_dum_2-0.909446214381
# Electrical_dum_2-0.895321807785
# RoofStyle_dum_2-0.887558075576
# BsmtFinType1_dum_2-0.879087075527
# Heating_dum_1-0.810918571501
# Condition1_dum_2-0.790047295969
# Fence_dum_0-0.781913779847
# EnclosedPorch-0.771211271586
# Exterior1st_dum_0-0.761559737834
# Alley_dum_1-0.752886887353
# HeatingQC_dum_2-0.748831470442
# BsmtQual_dum_0-0.738645641162
# Electrical_dum_0-0.712732749859
# YrSold-0.69779802415
# KitchenAbvGr-0.64661738871
# MoSold-0.620580416397
# KitchenQual_dum_2-0.630968947142
# ExterQual_dum_2-0.630980884366
# GarageFinish_dum_2-0.63218491879
# PoolQC_dum_2-0.631164946361
# Exterior2nd_dum_4-0.630965618348
# HouseStyle_dum_3-0.630965544763
# Condition2_dum_3-0.630965523248
# LandContour_dum_2-0.630965406476
# LotShape_dum_2-0.630965407456
# Exterior2nd_dum_2-0.587828810583
# BsmtFinType2_dum_1-0.576781277016
# Functional_dum_1-0.559939438828
# Fence_dum_1-0.554101636465
# ExterCond_dum_0-0.556446763533
# Condition1_dum_3-0.514382451538
# LowQualFinSF-0.500451572851
# GarageFinish_dum_0-0.47197936611
# MasVnrType_dum_0-0.413372284988
# Exterior2nd_dum_1-0.451627199229
# GarageCond_dum_1-0.404008521237
# PavedDrive_dum_1-0.38716210838
# RoofStyle_dum_1-0.386026621458
# MiscFeature_dum_0-0.35434600352
# SaleType_dum_3-0.365243304685
# GarageQual_dum_1-0.346332588589
# KitchenQual_dum_0-0.34293515425
# Heating_dum_2-0.327359396121
# Fence_dum_2-0.306039044929
# RoofMatl_dum_0-0.298432514161
# BsmtFinSF2-0.2381779928
# Functional_dum_2-0.295314575326
# Condition1_dum_1-0.247206901833
# HouseStyle_dum_1-0.242010077064
# GarageFinish_dum_1-0.235619793032
# PavedDrive_dum_0-0.208348866909
# MiscFeature_dum_2-0.197246017429
# SaleType_dum_1-0.195372060079
# BsmtCond_dum_0-0.17855071124
# Functional_dum_0-0.17664293285
# MSZoning_dum_2-0.191983177
# Electrical_dum_1-0.145379803679
# MiscFeature_dum_1-0.149526476614
# Foundation_dum_1-0.131764773352
# Condition2_dum_1-0.153040130719
# BsmtFinType2_dum_2-0.121135236054
# LotConfig_dum_0-0.116535320164
# Alley_dum_0-0.11886770301
# LotConfig_dum_1-0.101922655962
# BsmtExposure_dum_0-0.112498500373
# GarageQual_dum_2-0.0908656639759
# Utilities_dum_AllPub-0.0740072153569
# LandContour_dum_1-0.074124613345
# BldgType_dum_1-0.0846244218158
# ExterCond_dum_1-0.0644722137114
# Exterior1st_dum_3-0.0448298153581

# %%
cols_dropped.remove('SalePrice')

# %%
len(cols_dropped)
# Out:
# 76

# %%
df.shape
# Out:
# (1168, 138)

# %%
df.drop(cols_dropped,axis=1,inplace=True)

# %%
df.columns
# Out:
# Index([u'OverallCond', u'BsmtUnfSF', u'BsmtFullBath', u'BsmtHalfBath',
#        u'HalfBath', u'BedroomAbvGr', u'GarageCars', u'WoodDeckSF',
#        u'OpenPorchSF', u'3SsnPorch', u'ScreenPorch', u'SalePrice',
#        u'MSZoning_dum_0', u'MSZoning_dum_1', u'Street_dum_Pave',
#        u'LotShape_dum_0', u'LotShape_dum_1', u'LandContour_dum_0',
#        u'LandSlope_dum_0', u'LandSlope_dum_1', u'Neighborhood_dum_0',
#        u'Neighborhood_dum_2', u'Neighborhood_dum_3', u'Neighborhood_dum_4',
#        u'Condition1_dum_0', u'Condition2_dum_0', u'Condition2_dum_2',
#        u'BldgType_dum_0', u'BldgType_dum_2', u'HouseStyle_dum_0',
#        u'RoofStyle_dum_0', u'RoofMatl_dum_1', u'RoofMatl_dum_2',
#        u'Exterior1st_dum_1', u'Exterior1st_dum_3', u'Exterior2nd_dum_3',
#        u'MasVnrType_dum_1', u'ExterQual_dum_0', u'ExterQual_dum_1',
#        u'ExterCond_dum_2', u'BsmtQual_dum_1', u'BsmtCond_dum_1',
#        u'BsmtCond_dum_2', u'BsmtExposure_dum_1', u'BsmtFinType1_dum_0',
#        u'BsmtFinType1_dum_1', u'Heating_dum_0', u'HeatingQC_dum_0',
#        u'HeatingQC_dum_1', u'CentralAir_dum_Y', u'KitchenQual_dum_1',
#        u'FireplaceQu_dum_0', u'FireplaceQu_dum_1', u'FireplaceQu_dum_2',
#        u'GarageType_dum_0', u'GarageType_dum_2', u'PoolQC_dum_0',
#        u'PoolQC_dum_1', u'SaleType_dum_2', u'SaleCondition_dum_0',
#        u'SaleCondition_dum_1', u'SaleCondition_dum_2'],
#       dtype='object')

# %%
os.chdir('../output_data')

# %%
df.to_csv('train_v05.csv')

# %%
os.chdir('../pickles')

# %%
pickle.dump(vif_drop_cols,open('vif_drop_cols.pickle','wb'))

# %%
pickle.dump(cols_dropped,open('backward_drop_cols.pickle','wb'))

# %%
df.shape
# Out:
# (1168, 62)

# %%
df['SalePrice']
# Out:
# Id
# 39      109000
# 788     233000
# 1326     55000
# 1299    160000
# 152     372402
# 78      127000
# 110     190000
# 10      118000
# 997     136500
# 886     328900
# 1312    203000
# 1058    248000
# 200     274900
# 293     131000
# 1267    122000
# 1366    216000
# 1405    105000
# 1101     60000
# 1406    275000
# 1246    178000
# 945     137500
# 534      39300
# 804     582933
# 1223    143000
# 846     171000
# 281     228500
# 833     237000
# 151     122000
# 1036     84000
# 877     132250
#          ...
# 1420    223000
# 1240    265900
# 326      87000
# 614     147000
# 139     230000
# 570     135960
# 1376    239000
# 73      185000
# 602     141000
# 1331    227000
# 463      62383
# 1303    290000
# 574     170000
# 415     228000
# 971     135000
# 883     178000
# 378     340000
# 401     245500
# 461     263435
# 5       250000
# 974     182000
# 1131    135000
# 1277    162000
# 1228    147000
# 743     179000
# 253     173000
# 727     222000
# 1293    107500
# 191     315000
# 92       98600
# Name: SalePrice, Length: 1168, dtype: int64

# %%
os.chdir('../Statistics')

# %%
edd = pd.read_csv('edd_v04.csv',header=0)

# %%
edd.loc[edd['Var'].isin(cols_dropped),'Status']='drop'

# %%
edd.loc[edd['Var'].isin(cols_dropped),'Reason']='Backward Selection'

# %%
edd.to_csv('edd_v05.csv',index=False)

# %%
os.chdir('../pickles')

# %%
numericals_final = list(set(set(df.columns) & set(numerical)))

# %%
len(numericals_final)
# Out:
# 12

# %%
numericals_final
# Out:
# ['3SsnPorch',
#  'BsmtUnfSF',
#  'ScreenPorch',
#  'BsmtFullBath',
#  'OpenPorchSF',
#  'HalfBath',
#  'OverallCond',
#  'BsmtHalfBath',
#  'SalePrice',
#  'GarageCars',
#  'BedroomAbvGr',
#  'WoodDeckSF']

# %%
dummies_final = [col for col in df.columns if 'dum' in col]

# %%
len(dummies_final)
# Out:
# 50

# %%
pickle.dump(numericals_final,open('numerical_final.pickle','wb'))
pickle.dump(dummies_final,open('dummies_final.pickle','wb'))

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA

# %%
scale = StandardScaler()

# %%
scale.fit(np.array(df.drop(['SalePrice'],axis=1)))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
pickle.dump(scale,open('scale.pickle','wb'))

# %%
x = scale.transform(df.drop(['SalePrice'],axis=1))

# %%
df.shape
# Out:
# (1168, 62)

# %%
pca = PCA(n_components=61)

# %%
pca.fit(x)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=61, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
variance_cumulative = np.cumsum(pca.explained_variance_ratio_)

# %%
for i in range(61):
    if variance_cumulative[i]>=.9:
        n_components=i+1
        break

# %%
n_components
# Out:
# 47

# %%
pca = PCA(n_components=n_components)

# %%
pca.fit(x)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=47, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
pickle.dump(pca,open('pca.pickle','wb'))

# %%
df_pca_weights = pd.DataFrame(pca.components_,columns=df.drop(['SalePrice'],axis=1).columns,index=['pc'+str(i)
                                                                                                  for i in range(1,n_components+1)])

# %%
df_pca_magnitude_weights = pd.DataFrame(map(np.square,pca.components_),columns=df.drop(['SalePrice'],axis=1).columns,index=['pc'+str(i)
                                                                                                  for i in range(1,n_components+1)])

# %%
df_pca_weights
# Out:
#       OverallCond  BsmtUnfSF  BsmtFullBath  BsmtHalfBath  HalfBath  \
# pc1     -0.136811   0.158387      0.092586     -0.034619  0.163099
# pc2     -0.042981   0.162888      0.001554     -0.042144 -0.184596
# pc3      0.099143  -0.228056      0.324759      0.083765  0.015332
# pc4      0.016527   0.020268     -0.226915      0.002708  0.370116
# pc5     -0.149814  -0.156868      0.083607     -0.034545  0.073610
# pc6     -0.240299   0.010176      0.070944      0.013256 -0.053480
# pc7      0.082538  -0.252542      0.200490     -0.087812  0.101966
# pc8      0.228079   0.034864     -0.133441      0.174553  0.012831
# pc9      0.116222   0.167308     -0.163058     -0.022409 -0.041672
# pc10    -0.220927   0.095461     -0.001354     -0.104728 -0.203228
# pc11    -0.022405  -0.114000      0.081947     -0.079838  0.030435
# pc12     0.028671  -0.228554      0.217898     -0.148093  0.041226
# pc13     0.084579   0.151883     -0.074084     -0.080223 -0.120574
# pc14    -0.119475   0.138595     -0.162618     -0.011206  0.023539
# pc15    -0.002815  -0.163768     -0.103585      0.259397  0.111355
# pc16     0.019023  -0.005035     -0.074200      0.423360 -0.145012
# pc17    -0.058251   0.006840     -0.007352     -0.114806  0.071987
# pc18     0.051467   0.028029      0.082910      0.032941 -0.004253
# pc19    -0.036749  -0.002330     -0.007431     -0.132112  0.111720
# pc20    -0.047823   0.082458      0.065193     -0.171131 -0.073144
# pc21     0.099167  -0.003245     -0.088273      0.171892  0.045204
# pc22    -0.214140  -0.007382      0.079923     -0.213435  0.020125
# pc23    -0.079311  -0.040535     -0.019380     -0.139545  0.093434
# pc24     0.039159  -0.069555     -0.058208      0.250853 -0.038819
# pc25     0.100566   0.009492      0.092182      0.156204 -0.101553
# pc26    -0.021849   0.124888     -0.008553     -0.159774  0.027668
# pc27    -0.054068   0.108380     -0.034766      0.096980  0.000060
# pc28     0.185548  -0.009230      0.083192     -0.046313 -0.029817
# pc29    -0.165962  -0.144549      0.094693     -0.173076  0.142498
# pc30     0.294425  -0.070331      0.067160     -0.046233  0.012706
# pc31     0.104153   0.160757      0.122998     -0.201031  0.127966
# pc32    -0.061966  -0.128887     -0.079853      0.198263  0.139759
# pc33    -0.164359  -0.050704     -0.021423     -0.127694 -0.088371
# pc34     0.211887   0.007709     -0.046763     -0.178959 -0.055006
# pc35    -0.283748   0.023149     -0.117738      0.207379  0.141305
# pc36     0.116196  -0.197894      0.037023     -0.163170  0.112294
# pc37     0.006958   0.074776     -0.076543     -0.057781  0.001728
# pc38    -0.062107   0.006758      0.104596      0.018805 -0.047028
