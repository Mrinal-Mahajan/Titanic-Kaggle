# %%
import pandas as pd
import numpy as np
import pickle
import os

# %%
from scipy.stats import skew,kurtosis

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression

# %%
os.chdir('../output_data')

# %%
df = pd.read_csv('train_v01.csv',header=0)

# %%
df.set_index('Id',inplace=True)

# %%
os.chdir('../pickles')

# %%
numerical = pickle.load(open('numerical.pickle','rb'))

# %%
categorical = pickle.load(open('categorical.pickle','rb'))

# %%
os.chdir('../Statistics')

# %%
edd_actual = pd.read_csv('edd_v02.csv',header=0)

# %%
os.chdir('../Graphs/Box_Plot')

# %%
def graph_boxplot_univariate(s2):
    fig=plt.figure()
    plt.boxplot(list(df.loc[df[s2].notnull(),s2]))
    plt.xlabel(s2)
    plt.ylabel('values')
    plt.title('Univariate Ananlysis of '+s2)
    plt.show()
    try:
        fig.savefig(col+'.jpg')
    except:
        pass

# %%
for col in numerical:
    graph_boxplot_univariate(col)

# %%
def edd(data):
    df_desc = data.describe().transpose()
    df_desc['Var'] = df_desc.index
    df_desc.reset_index(inplace=True)
    df_desc.drop('count',axis=1,inplace=True)
    df_desc['skewness'] = df_desc['Var'].apply(lambda x: skew(np.array(data.loc[data[x].notnull(),x])))
    df_desc['kurtosis'] = df_desc['Var'].apply(lambda x: kurtosis(np.array(data.loc[data[x].notnull(),x]),fisher=False))
    df_desc['99%'] = df_desc['Var'].apply(lambda x: data[x].quantile(.99))
    df_desc['95%'] = df_desc['Var'].apply(lambda x: data[x].quantile(.95))
    df_desc['90%'] = df_desc['Var'].apply(lambda x: data[x].quantile(.90))
    df_desc['10%'] = df_desc['Var'].apply(lambda x: data[x].quantile(.1))
    df_desc['5%'] = df_desc['Var'].apply(lambda x: data[x].quantile(.05))
    df_desc['1%'] = df_desc['Var'].apply(lambda x: data[x].quantile(.01))
    df_desc['mean-3sigma'] = df_desc['mean'] - 3*df_desc['std']
    df_desc['mean+3sigma'] = df_desc['mean'] + 3*df_desc['std']
    df_desc['mean-2sigma'] = df_desc['mean'] - 2*df_desc['std']
    df_desc['mean+2sigma'] = df_desc['mean'] + 2*df_desc['std']
    df_desc['type']='numeric'
    
    def is_category(col):
        return 'float' not in str(data[col].dtype) and 'int' not in str(data[col].dtype)
    
    categorical = [col for col in data.columns if is_category(col)]
    df_categorical = pd.DataFrame()
    df_categorical['Var']=np.array(categorical)
    
    df_categorical['type']='categorical'
    for col in [c for c in df_desc.columns if c not in ['Var','type']]:
        df_categorical[col]=np.nan
    for col in categorical:
        df_var = data[col].value_counts()
        df_cat = pd.DataFrame()
        df_cat['count']=df_var
        df_cat['categories']=df_var.index
        df_cat.reset_index(inplace=True)
        df_cat.sort_values(by='count',ascending=False,inplace=True)
        df_cat.set_index('categories',inplace=True)
        index_list = df_cat.index.tolist()
        for i,c in enumerate(['mean','min','1%','5%','10%','25%']):
            try:
                df_categorical.loc[df_categorical['Var']==col,c] = index_list[i]
            except:
                break
        for i,c in enumerate(['50%','75%','90%','95%','99%','max']):
            try:
                df_categorical.loc[df_categorical['Var']==col,c] = index_list[-(i+1)]
            except:
                break
        del df_var
        del df_cat
        del index_list
    df_categorical = df_categorical[df_desc.columns]
    edd = pd.concat([df_desc,df_categorical])
    del df_desc
    del df_categorical
    edd['count'] = edd['Var'].apply(lambda x: data[data[x].notnull()].shape[0])
    edd['nmiss'] = data.shape[0]-edd['count']
    edd['missing_rate'] = np.array(edd['nmiss']).astype('float')/data.shape[0] * 100
    edd['unique'] = edd['Var'].apply(lambda x: len(data[x].value_counts().index.tolist()))
    orig_cols = ['mean','min','1%','5%','10%','25%','50%','75%','90%','95%','99%','max']
    new_cols = ['mean_or_top1','min_or_top2','p1_or_top3','p5_or_top4','p10_or_top5','p25_or_top6',
                'p50_or_bottom6','p75_or_bottom5','p90_or_bottom4','p95_or_bottom3','p99_or_bottom2','max_or_bottom1']
    
    convert_dict = {}
    for i in range(len(orig_cols)):
        convert_dict[orig_cols[i]]=new_cols[i]
    edd.rename(columns=convert_dict,inplace=True)
    edd = edd[['Var','type','count','nmiss','missing_rate','unique','std','skewness','kurtosis','mean-3sigma',
               'mean-2sigma','mean_or_top1','min_or_top2','p1_or_top3','p5_or_top4','p10_or_top5','p25_or_top6',
               'p50_or_bottom6','p75_or_bottom5','p90_or_bottom4','p95_or_bottom3','p99_or_bottom2','max_or_bottom1'
              ,'mean+2sigma','mean+3sigma']]
    return edd

# %%
edd_transformed = edd(df)

# %%
os.chdir('../../Statistics')

# %%
edd_transformed.to_csv('edd_transformed.csv',index=False)

# %%
def exponential_smoothning(data,s,p1,p5,p95,p99,alpha=.5,high=True,low=True):
    if alpha<=0 or alpha>=1:
        raise ValueError('alpha should be between 0 and 1')
    data.sort_values(s,ascending=True,inplace=True)
    if high==True:
        def get_st_increasing(array,alpha):
            st = array[0]
            i=1
            while i < len(array):
                st = alpha*array[i]+(1-alpha)*st
                i+=1
            return st
        s0 = get_st_increasing(list(np.array(data.loc[(data[s]>=p95) & (data[s]<=p99) & (data[s].notnull()),s])),alpha)
        
        for i in data[(data[s]>p99) & (data[s].notnull())].index.tolist():
            data.loc[i,s] = alpha*data.loc[i,s] + (1-alpha)*s0
            s0 = data.loc[i,s]
            
        if low==True:
            def get_st_decreasing(array,alpha):
                st = array[-1]
                i=len(array)-2
                while i > 0:
                    st = alpha*array[i+1]+(1-alpha)*st
                    i-=1
                return st
            s0 = get_st_decreasing(list(np.array(data.loc[(data[s]>=p1) & (data[s]<=p5) & (data[s].notnull()),s])),alpha)

            for i in data[(data[s]<p1) & (data[s].notnull())].index.tolist()[::-1]:
                data.loc[i,s] = alpha*data[s].loc[i,s] + (1-alpha)*s0
                s0 = data.loc[i,s]

# %%
def capping_and_flooring(data,s,a,b,high=True,low=True):
    if high==True:
        data.loc[(data[s]>a) & (data[s].notnull()),s] =a
    if low==True:
        data.loc[(data[s]<b) & (data[s].notnull()),s] = b

# %%
def automatic_outlier_treatment(data,s):
    
    lower_limit = data[s].quantile(q=.25)-1.5*(data[s].quantile(q=.75)-data[s].quantile(q=.25))
    upper_limit = data[s].quantile(q=.75)+1.5*(data[s].quantile(q=.75)-data[s].quantile(q=.25))

    frac_lower = float(np.unique(np.array(data[(data[s]<lower_limit) & (data[s].notnull())])).shape[0])/df.shape[0]
    frac_upper = float(np.unique(np.array(data[(data[s]>upper_limit) & (data[s].notnull())])).shape[0])/df.shape[0]

    p1,low_sigma3,low_sigma2 = data[s].quantile(q=.01),data[s].mean()-3*data[s].std(),data[s].mean()-2*data[s].std()
    p99,high_sigma3,high_sigma2 = data[s].quantile(q=.99),data[s].mean()+3*data[s].std(),data[s].mean()+2*data[s].std()
    p5,p95 = data[s].quantile(q=.05),data[s].quantile(q=.95)
    minima,maxima = data[s].min(),data[s].max()

    #deriving lower limit in case of aggresive treatment
    if low_sigma3 >= minima:
        b = min(p1,low_sigma3)
    elif low_sigma2>= minima:
        b = min(p1,low_sigma2)
    else:
        b=p1

    #deriving upper limit in case of aggresive treatment
    if high_sigma3 <= maxima:
        a = max(p99,high_sigma3)
    elif high_sigma2<= maxima:
        a = max(p99,high_sigma2)
    else:
        a=p99

    outlier_treatment = ''

    #lower end outlier treatment
    if frac_lower<=.05:
        capping_and_flooring(data,s,a,b,high=False,low=True)
        if b==p1:
            outlier_treatment+='flooring at p1,'
        elif b==low_sigma2:
            outlier_treatment+='flooring at sigma2,'
        elif b==low_sigma3:
            outlier_treatment+='flooring at sigma3,'
    else:
        try:
            exponential_smoothning(data,s,p1,p5,p95,p99,low=True,high=False)
            outlier_treatment+='lower line exponential smoothing,'
        except:
            pass

    #higher end outlier treatment
    if frac_upper<=.05:
        capping_and_flooring(data,s,a,b,high=True,low=False)
        if b==p1:
            outlier_treatment+='capping at p99'
        elif b==low_sigma2:
            outlier_treatment+='capping at sigma2'
        elif b==low_sigma3:
            outlier_treatment+='Capping at sigma3'
    else:
        try:
            exponential_smoothning(data,s,p1,p5,p95,p99,low=False,high=True)
            outlier_treatment+='higher line exponential smoothing'
        except:
            pass

    return outlier_treatment

# %%
edd_actual['outlier_treatment'] = ''
for col in [x for x in numerical if x != 'SalePrice']:
    edd_actual.loc[edd_actual['Var']==col,'outlier_treatment']=automatic_outlier_treatment(df,col)

# %%
edd_actual['outlier_treatment'].value_counts()
# Out:
#                                                                       44
# flooring at p1,higher line exponential smoothing                      22
# flooring at p1,capping at p99                                          7
# lower line exponential smoothing,higher line exponential smoothing     5
# lower line exponential smoothing,Capping at sigma3                     1
# flooring at sigma3,Capping at sigma3                                   1
# Name: outlier_treatment, dtype: int64

# %%
os.chdir('../output_data')

# %%
df.to_csv('train_v02.csv')

# %%
os.chdir('../Statistics')

# %%
edd_actual.to_csv('edd_v03.csv',index=False)

# %% [markdown]
# # Imputation

# %%
conversion_dict={}

# %%
def make_dummies(data,s):
    conversion_list = []
    df_value = pd.DataFrame()
    df_value['counts'] = data[s].value_counts()
    df_value.sort_values(by='counts',ascending=False,inplace=True)
    for category in df_value.index.tolist()[:-1]:
        conversion_list.append(category)
        data[s+'_dum_'+str(category)] = 0
        data.loc[data[s]==category,s+'_dum_'+str(category)]=1
    data.drop(s,axis=1,inplace=True)
    print(s+' done')
    return conversion_list

# %%
def make_dummies_binary(data,s):
    df_value=pd.DataFrame()
    df_value['counts']=data[s].value_counts()
    df_value.sort_values(by='counts',ascending=False,inplace=True)
    categories = df_value.index.tolist()
    total_categories = len(categories)
    dummies = len(str(int(bin(total_categories)[2:],10)))
    bin_conv=[]
    for i in range(total_categories):
        bin_conv.append(int(bin(i)[2:],10))
    conv_list=[]
    for i,cat in enumerate(categories):
        conv_list.append((cat,bin_conv[i]))
    for j in range(dummies):
        data[s+'_dum_'+str(j)]=0
        for i,cat in enumerate(categories):
            data.loc[data[s]==cat,s+'_dum_'+str(j)]=bin_conv[i]%10
            bin_conv[i]=bin_conv[i]//10
    data.drop(s,axis=1,inplace=True)
    print(s+' done')
    return conv_list

# %%
values={}
for col in categorical:
    values[col]='Unknown'
df.fillna(values,inplace=True)
# Out:
#       MSSubClass MSZoning  LotFrontage    LotArea Street    Alley LotShape  \
# Id
# 39        8000.0       RL     8.246211   8.977399   Pave  Unknown      Reg
# 788     216000.0       RL     8.717798   9.224440   Pave  Unknown      IR1
# 1326     27000.0       RM     6.324555   8.198639   Pave  Unknown      Reg
# 1299    216000.0       RL    16.574547  10.988287   Pave  Unknown      IR3
# 152       8000.0       RL    10.344080   9.538996   Pave  Unknown      Reg
# 78      125000.0       RM     7.071068   9.063579   Pave  Unknown      Reg
# 110       8000.0       RL    10.246951   9.371694   Pave  Unknown      IR1
# 10     6859000.0       RL     7.071068   8.911934   Pave  Unknown      Reg
# 997       8000.0       RL          NaN   9.274160   Pave  Unknown      IR1
# 886    1728000.0       FV     7.071068   8.540714   Pave  Unknown      IR1
# 1312      8000.0       RL     8.246211   9.084097   Pave  Unknown      Reg
# 1058    216000.0       RL          NaN  10.307585   Pave  Unknown      IR2
# 200       8000.0       RL     8.717798   9.168580   Pave  Unknown      Reg
# 293     125000.0       RL     7.745967   9.342158   Pave  Unknown      Reg
# 1267   6859000.0       RM     7.745967   9.222269   Pave  Unknown      IR1
# 1366    216000.0       FV          NaN   8.922658   Pave  Unknown      Reg
# 1405    125000.0       RL     7.745967   9.250522   Pave     Grvl      Reg
# 1101     27000.0       RL     7.745967   9.035987   Pave  Unknown      Reg
# 1406   1728000.0       RM     6.633250   8.253748   Pave  Unknown      IR1
# 1246    512000.0       RL     8.831761   9.400134   Pave  Unknown      Reg
# 945       8000.0       RL          NaN   9.573246   Pave  Unknown      IR1
# 534       8000.0       RL     7.071068   8.517193   Pave  Unknown      Reg
# 804     216000.0       RL    10.344080   9.538996   Pave  Unknown      Reg
# 1223    125000.0       RL     8.831761   9.258750   Pave  Unknown      Reg
# 846     614125.0       RL          NaN   9.719985   Pave  Unknown      IR1
# 281     216000.0       RL     9.055385   9.331407   Pave  Unknown      Reg
# 833     216000.0       RL     6.633250   9.164087   Pave  Unknown      IR1
# 151       8000.0       RL    10.954451   9.245321   Pave  Unknown      Reg
# 1036      8000.0       RL          NaN   9.350102   Pave  Unknown      IR1
# 877       8000.0       RL     9.695360  10.138006   Pave  Unknown      Reg
# ...          ...      ...          ...        ...    ...      ...      ...
# 1420      8000.0       RL          NaN   9.703877   Pave  Unknown      IR1
# 1240      8000.0       RL     8.000000   9.109083   Pave  Unknown      IR1
# 326      91125.0       RM     7.071068   8.517193   Pave  Unknown      Reg
# 614       8000.0       RL     8.366600   9.036225   Pave  Unknown      Reg
# 139     216000.0       RL     8.544004   9.112286   Pave  Unknown      IR1
# 570     729000.0       RL          NaN   8.858226   Pave  Unknown      IR1
# 1376      8000.0       RL     9.433981   9.304832   Pave  Unknown      IR1
# 73      216000.0       RL     8.602325   9.224342   Pave  Unknown      IR1
# 602     125000.0       RM     7.071068   9.104980   Pave  Unknown      Reg
# 1331      8000.0       RL     9.219544   9.210340   Pave  Unknown      Reg
# 463       8000.0       RL     7.745967   9.021719   Pave  Unknown      IR1
# 1303    216000.0       RL     9.591663   9.222269   Pave  Unknown      Reg
# 574     512000.0       RL     8.717798   9.207035   Pave  Unknown      IR1
# 415     216000.0       RL     7.681146   9.326166   Pave  Unknown      IR2
# 971     125000.0       RL     7.745967   9.287301   Pave  Unknown      Reg
# 883     216000.0       RL          NaN   9.173261   Pave  Unknown      IR1
# 378     216000.0       FV    10.099505   9.318567   Pave  Unknown      IR1
# 401    1728000.0       RL     6.164414   9.613336   Pave  Unknown      IR2
# 461     216000.0       FV     8.660254   8.987697   Pave  Unknown      IR1
# 5       216000.0       RL     9.165151   9.565214   Pave  Unknown      IR1
# 974       8000.0       FV     9.746794   9.362117   Pave  Unknown      Reg
# 1131    125000.0       RL     8.062258   8.962392   Pave  Unknown      Reg
# 1277    216000.0       RL          NaN   9.467769   Pave  Unknown      IR1
# 1228      8000.0       RL     8.485281   9.090656   Pave  Unknown      Reg
# 743       8000.0       RL     8.062258   9.041922   Pave  Unknown      Reg
# 253     216000.0       RL     8.062258   9.031931   Pave  Unknown      IR1
# 727       8000.0       RL          NaN   9.984837   Pave  Unknown      IR1
# 1293    343000.0       RM     7.745967   8.794825   Pave  Unknown      Reg
# 191     343000.0       RL     8.366600   9.265775   Pave  Unknown      Reg
# 92        8000.0       RL     9.219544   9.047821   Pave  Unknown      Reg
#
#      LandContour Utilities LotConfig    ...      PoolArea   PoolQC    Fence  \
# Id                                      ...
# 39           Lvl    AllPub    Inside    ...      0.000000  Unknown  Unknown
# 788          Lvl    AllPub    Inside    ...      0.000000  Unknown  Unknown
# 1326         Lvl    AllPub    Inside    ...      0.000000  Unknown    MnPrv
# 1299         Bnk    AllPub    Corner    ...      3.914868       Gd  Unknown
# 152          Lvl    AllPub    Inside    ...      0.000000  Unknown  Unknown
# 78           Lvl    AllPub    Inside    ...      0.000000  Unknown    MnPrv
# 110          Lvl    AllPub    Inside    ...      0.000000  Unknown    MnPrv
# 10           Lvl    AllPub    Corner    ...      0.000000  Unknown  Unknown
# 997          Lvl    AllPub    Inside    ...      0.000000  Unknown  Unknown
# 886          Lvl    AllPub   CulDSac    ...      0.000000  Unknown  Unknown
# 1312         Lvl    AllPub    Inside    ...      0.000000  Unknown  Unknown
# 1058         Lvl    AllPub       FR2    ...      0.000000  Unknown  Unknown
# 200          Lvl    AllPub    Inside    ...      0.000000  Unknown  Unknown
# 293          Lvl    AllPub    Inside    ...      0.000000  Unknown  Unknown
# 1267         Bnk    AllPub    Inside    ...      0.000000  Unknown    MnPrv
# 1366         Lvl    AllPub    Inside    ...      0.000000  Unknown  Unknown
# 1405         Lvl    AllPub    Corner    ...      0.000000  Unknown    MnPrv
# 1101         Bnk    AllPub    Inside    ...      0.000000  Unknown  Unknown
# 1406         HLS    AllPub    Inside    ...      0.000000  Unknown  Unknown
# 1246         Lvl    AllPub    Inside    ...      0.000000  Unknown  Unknown
# 945          Lvl    NoSeWa   CulDSac    ...      0.000000  Unknown  Unknown
# 534          Low    AllPub    Inside    ...      0.000000  Unknown  Unknown
# 804          Lvl    AllPub    Inside    ...      0.000000  Unknown  Unknown
# 1223         Lvl    AllPub    Inside    ...      0.000000  Unknown     GdWo
# 846          Lvl    AllPub   CulDSac    ...      0.000000  Unknown  Unknown
# 281          Lvl    AllPub    Inside    ...      0.000000  Unknown  Unknown
# 833          Lvl    AllPub   CulDSac    ...      0.000000  Unknown  Unknown
# 151          Lvl    AllPub    Corner    ...      0.000000  Unknown    MnPrv
# 1036         Lvl    AllPub   CulDSac    ...      0.000000  Unknown  Unknown
# 877          HLS    AllPub    Inside    ...      0.000000  Unknown  Unknown
# ...          ...       ...       ...    ...           ...      ...      ...
# 1420         Lvl    AllPub    Inside    ...      0.000000  Unknown  Unknown
# 1240         HLS    AllPub    Inside    ...      0.000000  Unknown  Unknown
# 326          Lvl    AllPub    Inside    ...      0.000000  Unknown  Unknown
# 614          Lvl    AllPub    Inside    ...      0.000000  Unknown  Unknown
# 139          Lvl    AllPub    Inside    ...      0.000000  Unknown    GdPrv
# 570          Lvl    AllPub    Corner    ...      0.000000  Unknown  Unknown
# 1376         HLS    AllPub    Inside    ...      0.000000  Unknown  Unknown
# 73           Lvl    AllPub    Corner    ...      0.000000  Unknown  Unknown
# 602          Bnk    AllPub    Inside    ...      0.000000  Unknown  Unknown
# 1331         Lvl    AllPub    Inside    ...      0.000000  Unknown  Unknown
# 463          Lvl    AllPub    Inside    ...      0.000000  Unknown     GdWo
# 1303         Lvl    AllPub    Inside    ...      0.000000  Unknown  Unknown
# 574          Lvl    AllPub    Inside    ...      0.000000  Unknown  Unknown
# 415          Lvl    AllPub   CulDSac    ...      0.000000  Unknown  Unknown
# 971          Lvl    AllPub    Inside    ...      0.000000  Unknown  Unknown
# 883          Lvl    AllPub    Corner    ...      0.000000  Unknown    MnPrv
# 378          Lvl    AllPub    Corner    ...      0.000000  Unknown  Unknown
# 401          Lvl    AllPub    Inside    ...      0.000000  Unknown  Unknown
# 461          Lvl    AllPub    Inside    ...      0.000000  Unknown  Unknown
# 5            Lvl    AllPub       FR2    ...      0.000000  Unknown  Unknown
# 974          Lvl    AllPub    Corner    ...      0.000000  Unknown  Unknown
# 1131         Lvl    AllPub    Inside    ...      0.000000  Unknown    MnPrv
# 1277         Lvl    AllPub   CulDSac    ...      0.000000  Unknown  Unknown
# 1228         Lvl    AllPub    Corner    ...      0.000000  Unknown  Unknown
# 743          Lvl    AllPub    Inside    ...      0.000000  Unknown    GdPrv
# 253          Lvl    AllPub    Inside    ...      0.000000  Unknown  Unknown
# 727          Lvl    AllPub    Corner    ...      0.000000  Unknown  Unknown
# 1293         Lvl    AllPub    Corner    ...      0.000000  Unknown  Unknown
# 191          Bnk    AllPub    Inside    ...      0.000000  Unknown  Unknown
# 92           Lvl    AllPub    Inside    ...      0.000000  Unknown     GdWo
#
#      MiscFeature MiscVal MoSold        YrSold  SaleType  SaleCondition  \
# Id
# 39       Unknown     0.0    1.0  8.120601e+09        WD        Abnorml
# 788      Unknown     0.0    1.0  8.120601e+09        WD         Normal
# 1326     Unknown     0.0    1.0  8.096385e+09        WD         Normal
# 1299     Unknown     0.0    1.0  8.096385e+09       New        Partial
# 152      Unknown     0.0    1.0  8.096385e+09       New        Partial
# 78       Unknown     0.0    1.0  8.096385e+09        WD         Normal
# 110      Unknown     0.0    1.0  8.120601e+09       COD         Normal
# 10       Unknown     0.0    1.0  8.096385e+09        WD         Normal
# 997      Unknown     0.0    1.0  8.072216e+09       COD         Normal
# 886      Unknown     0.0    1.0  8.096385e+09       CWD        Abnorml
# 1312     Unknown     0.0    1.0  8.084294e+09       New        Partial
# 1058     Unknown     0.0    1.0  8.108487e+09        WD         Normal
# 200      Unknown     0.0    1.0  8.108487e+09        WD         Normal
# 293      Unknown     0.0    1.0  8.108487e+09        WD         Normal
# 1267     Unknown     0.0    1.0  8.084294e+09        WD         Normal
# 1366     Unknown     0.0    1.0  8.120601e+09        WD         Normal
# 1405     Unknown     0.0    1.0  8.072216e+09        WD         Family
# 1101     Unknown     0.0    1.0  8.108487e+09        WD         Normal
# 1406     Unknown     0.0    1.0  8.096385e+09        WD         Normal
# 1246     Unknown     0.0    1.0  8.084294e+09        WD        Abnorml
# 945      Unknown     0.0    1.0  8.108487e+09       COD        Abnorml
# 534      Unknown     0.0    1.0  8.084294e+09        WD         Normal
# 804      Unknown     0.0    1.0  8.108487e+09       New        Partial
# 1223     Unknown     0.0    1.0  8.084294e+09        WD         Normal
# 846      Unknown     0.0    1.0  8.084294e+09        WD         Normal
# 281      Unknown     0.0    1.0  8.084294e+09        WD         Normal
# 833      Unknown     0.0    1.0  8.120601e+09        WD         Normal
# 151      Unknown     0.0    1.0  8.084294e+09        WD         Normal
# 1036     Unknown     0.0    1.0  8.108487e+09        WD         Normal
# 877      Unknown     0.0    1.0  8.084294e+09        WD         Normal
# ...          ...     ...    ...           ...       ...            ...
# 1420     Unknown     0.0  144.0  8.072216e+09        WD         Normal
# 1240     Unknown     0.0  144.0  8.084294e+09        WD         Normal
# 326      Unknown     0.0  144.0  8.084294e+09        WD         Normal
# 614      Unknown     0.0  144.0  8.084294e+09       New        Partial
# 139      Unknown     0.0  144.0  8.096385e+09        WD         Normal
# 570      Unknown     0.0  144.0  8.072216e+09        WD         Normal
# 1376     Unknown     0.0  144.0  8.084294e+09       New        Partial
# 73       Unknown     0.0  144.0  8.108487e+09        WD         Normal
# 602      Unknown     0.0  144.0  8.084294e+09        WD         Normal
# 1331     Unknown     0.0  144.0  8.084294e+09        WD         Normal
# 463      Unknown     0.0  144.0  8.108487e+09        WD         Normal
# 1303     Unknown     0.0  144.0  8.072216e+09        WD         Normal
# 574      Unknown     0.0  144.0  8.084294e+09        WD         Normal
# 415      Unknown     0.0  144.0  8.096385e+09        WD         Normal
# 971      Unknown     0.0  144.0  8.072216e+09        WD        Abnorml
# 883      Unknown     0.0  144.0  8.108487e+09        WD         Normal
# 378      Unknown     0.0  144.0  8.084294e+09        WD         Normal
# 401      Unknown     0.0  144.0  8.096385e+09        WD         Normal
# 461      Unknown     0.0  144.0  8.108487e+09       New        Partial
# 5        Unknown     0.0  144.0  8.096385e+09        WD         Normal
# 974      Unknown     0.0  144.0  8.096385e+09       New        Partial
# 1131     Unknown     0.0  144.0  8.108487e+09        WD         Normal
# 1277     Unknown     0.0  144.0  8.108487e+09        WD         Normal
# 1228     Unknown     0.0  144.0  8.096385e+09        WD         Normal
# 743      Unknown     0.0  144.0  8.084294e+09        WD         Normal
# 253      Unknown     0.0  144.0  8.096385e+09        WD         Normal
# 727      Unknown     0.0  144.0  8.108487e+09        WD         Normal
# 1293     Unknown     0.0  144.0  8.108487e+09        WD         Normal
# 191      Unknown     0.0  144.0  8.084294e+09        WD         Normal
# 92       Unknown     0.0  144.0  8.072216e+09        WD        Abnorml
#
#       SalePrice
# Id
# 39       109000
# 788      233000
# 1326      55000
# 1299     160000
# 152      372402
# 78       127000
# 110      190000
# 10       118000
# 997      136500
# 886      328900
# 1312     203000
# 1058     248000
# 200      274900
# 293      131000
# 1267     122000
# 1366     216000
# 1405     105000
# 1101      60000
# 1406     275000
# 1246     178000
# 945      137500
# 534       39300
# 804      582933
# 1223     143000
# 846      171000
# 281      228500
# 833      237000
# 151      122000
# 1036      84000
# 877      132250
# ...         ...
# 1420     223000
# 1240     265900
# 326       87000
# 614      147000
# 139      230000
# 570      135960
# 1376     239000
# 73       185000
# 602      141000
# 1331     227000
# 463       62383
# 1303     290000
# 574      170000
# 415      228000
# 971      135000
# 883      178000
# 378      340000
# 401      245500
# 461      263435
# 5        250000
# 974      182000
# 1131     135000
# 1277     162000
# 1228     147000
# 743      179000
# 253      173000
# 727      222000
# 1293     107500
# 191      315000
# 92        98600
#
# [1168 rows x 80 columns]

# %%
df[categorical].isnull().any()
# Out:
# MSZoning         False
# Street           False
# Alley            False
# LotShape         False
# LandContour      False
# Utilities        False
# LotConfig        False
# LandSlope        False
# Neighborhood     False
# Condition1       False
# Condition2       False
# BldgType         False
# HouseStyle       False
# RoofStyle        False
# RoofMatl         False
# Exterior1st      False
# Exterior2nd      False
# MasVnrType       False
# ExterQual        False
# ExterCond        False
# Foundation       False
# BsmtQual         False
# BsmtCond         False
# BsmtExposure     False
# BsmtFinType1     False
# BsmtFinType2     False
# Heating          False
# HeatingQC        False
# CentralAir       False
# Electrical       False
# KitchenQual      False
# Functional       False
# FireplaceQu      False
# GarageType       False
# GarageFinish     False
# GarageQual       False
# GarageCond       False
# PavedDrive       False
# PoolQC           False
# Fence            False
# MiscFeature      False
# SaleType         False
# SaleCondition    False
# dtype: bool

# %%
for col in categorical:
    if len(df[col].value_counts().index.tolist())<=2:
        conversion_dict[col]=make_dummies(df,col)
    else:
        conversion_dict[col]=make_dummies_binary(df,col)
# Out:
# MSZoning done
# Street done
# Alley done
# LotShape done
# LandContour done
# Utilities done
# LotConfig done
# LandSlope done
# Neighborhood done
# Condition1 done
# Condition2 done
# BldgType done
# HouseStyle done
# RoofStyle done
# RoofMatl done
# Exterior1st done
# Exterior2nd done
# MasVnrType done
# ExterQual done
# ExterCond done
# Foundation done
# BsmtQual done
# BsmtCond done
# BsmtExposure done
# BsmtFinType1 done
# BsmtFinType2 done
# Heating done
# HeatingQC done
# CentralAir done
# Electrical done
# KitchenQual done
# Functional done
# FireplaceQu done
# GarageType done
# GarageFinish done
# GarageQual done
# GarageCond done
# PavedDrive done
# PoolQC done
# Fence done
# MiscFeature done
# SaleType done
# SaleCondition done

# %%
os.chdir('../pickles')

# %%
pickle.dump(conversion_dict,open('conversion_dict.pickle','wb'))

# %%
conversion_dict
# Out:
# {'Alley': [('Unknown', 0), ('Grvl', 1), ('Pave', 10)],
#  'BldgType': [('1Fam', 0),
#   ('TwnhsE', 1),
#   ('Duplex', 10),
#   ('Twnhs', 11),
#   ('2fmCon', 100)],
#  'BsmtCond': [('TA', 0), ('Gd', 1), ('Fa', 10), ('Unknown', 11), ('Po', 100)],
#  'BsmtExposure': [('No', 0),
#   ('Av', 1),
#   ('Gd', 10),
#   ('Mn', 11),
#   ('Unknown', 100)],
#  'BsmtFinType1': [('Unf', 0),
#   ('GLQ', 1),
#   ('ALQ', 10),
#   ('BLQ', 11),
#   ('Rec', 100),
#   ('LwQ', 101),
#   ('Unknown', 110)],
#  'BsmtFinType2': [('Unf', 0),
#   ('Rec', 1),
#   ('LwQ', 10),
#   ('Unknown', 11),
#   ('BLQ', 100),
#   ('ALQ', 101),
#   ('GLQ', 110)],
#  'BsmtQual': [('TA', 0), ('Gd', 1), ('Ex', 10), ('Fa', 11), ('Unknown', 100)],
#  'CentralAir': ['Y'],
#  'Condition1': [('Norm', 0),
#   ('Feedr', 1),
#   ('Artery', 10),
#   ('RRAn', 11),
#   ('PosN', 100),
#   ('RRAe', 101),
#   ('PosA', 110),
#   ('RRNn', 111),
#   ('RRNe', 1000)],
#  'Condition2': [('Norm', 0),
#   ('Feedr', 1),
#   ('Artery', 10),
#   ('PosN', 11),
#   ('RRAn', 100),
#   ('RRAe', 101),
#   ('PosA', 110),
#   ('RRNn', 111)],
#  'Electrical': [('SBrkr', 0),
#   ('FuseA', 1),
#   ('FuseF', 10),
#   ('FuseP', 11),
#   ('Unknown', 100)],
#  'ExterCond': [('TA', 0), ('Gd', 1), ('Fa', 10), ('Ex', 11), ('Po', 100)],
#  'ExterQual': [('TA', 0), ('Gd', 1), ('Ex', 10), ('Fa', 11)],
#  'Exterior1st': [('VinylSd', 0),
#   ('HdBoard', 1),
#   ('MetalSd', 10),
#   ('Wd Sdng', 11),
#   ('Plywood', 100),
#   ('CemntBd', 101),
#   ('BrkFace', 110),
#   ('Stucco', 111),
#   ('WdShing', 1000),
#   ('AsbShng', 1001),
#   ('BrkComm', 1010),
#   ('AsphShn', 1011),
#   ('ImStucc', 1100),
#   ('Stone', 1101),
#   ('CBlock', 1110)],
#  'Exterior2nd': [('VinylSd', 0),
#   ('Wd Sdng', 1),
#   ('MetalSd', 10),
#   ('HdBoard', 11),
#   ('Plywood', 100),
#   ('CmentBd', 101),
#   ('Wd Shng', 110),
#   ('Stucco', 111),
#   ('AsbShng', 1000),
#   ('BrkFace', 1001),
#   ('Brk Cmn', 1010),
#   ('ImStucc', 1011),
#   ('AsphShn', 1100),
#   ('Stone', 1101),
#   ('CBlock', 1110),
#   ('Other', 1111)],
#  'Fence': [('Unknown', 0),
#   ('MnPrv', 1),
#   ('GdPrv', 10),
#   ('GdWo', 11),
#   ('MnWw', 100)],
#  'FireplaceQu': [('Unknown', 0),
#   ('Gd', 1),
#   ('TA', 10),
#   ('Fa', 11),
#   ('Ex', 100),
#   ('Po', 101)],
#  'Foundation': [('PConc', 0),
#   ('CBlock', 1),
#   ('BrkTil', 10),
#   ('Slab', 11),
#   ('Stone', 100),
#   ('Wood', 101)],
#  'Functional': [('Typ', 0),
#   ('Min2', 1),
#   ('Min1', 10),
#   ('Mod', 11),
#   ('Maj1', 100),
#   ('Maj2', 101),
#   ('Sev', 110)],
#  'GarageCond': [('TA', 0),
#   ('Unknown', 1),
#   ('Fa', 10),
#   ('Gd', 11),
#   ('Po', 100),
#   ('Ex', 101)],
#  'GarageFinish': [('Unf', 0), ('RFn', 1), ('Fin', 10), ('Unknown', 11)],
#  'GarageQual': [('TA', 0),
#   ('Unknown', 1),
#   ('Fa', 10),
#   ('Gd', 11),
#   ('Ex', 100),
#   ('Po', 101)],
#  'GarageType': [('Attchd', 0),
#   ('Detchd', 1),
#   ('BuiltIn', 10),
#   ('Unknown', 11),
#   ('Basment', 100),
#   ('CarPort', 101),
#   ('2Types', 110)],
#  'Heating': [('GasA', 0),
#   ('GasW', 1),
#   ('Grav', 10),
#   ('Wall', 11),
#   ('OthW', 100),
#   ('Floor', 101)],
#  'HeatingQC': [('Ex', 0), ('TA', 1), ('Gd', 10), ('Fa', 11), ('Po', 100)],
#  'HouseStyle': [('1Story', 0),
#   ('2Story', 1),
#   ('1.5Fin', 10),
#   ('SLvl', 11),
#   ('SFoyer', 100),
#   ('1.5Unf', 101),
#   ('2.5Unf', 110),
#   ('2.5Fin', 111)],
#  'KitchenQual': [('TA', 0), ('Gd', 1), ('Ex', 10), ('Fa', 11)],
#  'LandContour': [('Lvl', 0), ('Bnk', 1), ('HLS', 10), ('Low', 11)],
#  'LandSlope': [('Gtl', 0), ('Mod', 1), ('Sev', 10)],
#  'LotConfig': [('Inside', 0),
#   ('Corner', 1),
#   ('CulDSac', 10),
#   ('FR2', 11),
#   ('FR3', 100)],
#  'LotShape': [('Reg', 0), ('IR1', 1), ('IR2', 10), ('IR3', 11)],
#  'MSZoning': [('RL', 0), ('RM', 1), ('FV', 10), ('RH', 11), ('C (all)', 100)],
#  'MasVnrType': [('None', 0),
#   ('BrkFace', 1),
#   ('Stone', 10),
#   ('BrkCmn', 11),
#   ('Unknown', 100)],
#  'MiscFeature': [('Unknown', 0),
#   ('Shed', 1),
#   ('Othr', 10),
#   ('Gar2', 11),
#   ('TenC', 100)],
#  'Neighborhood': [('NAmes', 0),
#   ('CollgCr', 1),
#   ('OldTown', 10),
#   ('Edwards', 11),
#   ('Somerst', 100),
#   ('NWAmes', 101),
#   ('Gilbert', 110),
#   ('NridgHt', 111),
#   ('Sawyer', 1000),
#   ('BrkSide', 1001),
#   ('Crawfor', 1010),
#   ('SawyerW', 1011),
#   ('Mitchel', 1100),
#   ('NoRidge', 1101),
#   ('Timber', 1110),
#   ('IDOTRR', 1111),
#   ('SWISU', 10000),
#   ('StoneBr', 10001),
#   ('ClearCr', 10010),
#   ('Blmngtn', 10011),
#   ('BrDale', 10100),
#   ('MeadowV', 10101),
#   ('Veenker', 10110),
#   ('NPkVill', 10111),
#   ('Blueste', 11000)],
#  'PavedDrive': [('Y', 0), ('N', 1), ('P', 10)],
#  'PoolQC': [('Unknown', 0), ('Ex', 1), ('Gd', 10), ('Fa', 11)],
#  'RoofMatl': [('CompShg', 0),
#   ('Tar&Grv', 1),
#   ('WdShngl', 10),
#   ('WdShake', 11),
#   ('Metal', 100),
#   ('ClyTile', 101),
#   ('Roll', 110)],
#  'RoofStyle': [('Gable', 0),
#   ('Hip', 1),
#   ('Flat', 10),
#   ('Gambrel', 11),
#   ('Mansard', 100),
#   ('Shed', 101)],
#  'SaleCondition': [('Normal', 0),
#   ('Partial', 1),
#   ('Abnorml', 10),
#   ('Family', 11),
#   ('Alloca', 100),
#   ('AdjLand', 101)],
#  'SaleType': [('WD', 0),
#   ('New', 1),
#   ('COD', 10),
#   ('ConLD', 11),
#   ('ConLw', 100),
#   ('CWD', 101),
#   ('ConLI', 110),
#   ('Con', 111),
#   ('Oth', 1000)],
#  'Street': ['Pave'],
#  'Utilities': ['AllPub']}

# %%
imputation_cols = [col for col in df.columns if col not in numerical]

# %%
pickle.dump(imputation_cols,open('imputation_cols.pickle','wb'))

# %%
os.chdir('../Imputation_models')

# %%
for col in [x for x in numerical if x!='SalePrice']:
    data = df[imputation_cols+[col]].dropna(subset=[col])
    x = np.array(data[imputation_cols])
    y = np.array(data[col])
    model = LinearRegression()
    model.fit(x,y)
    del x
    del y
    pickle.dump(model,open(col+'_impute.pickle','wb'))
    if df[col].isnull().any():
        indices = df.loc[df[col].isnull()].index.tolist()
        df.loc[indices,col]=np.array(model.predict(np.array(df.loc[indices,imputation_cols])))
        del indices
    del model
    print(col+' imputed')
# Out:
# MSSubClass imputed
# LotFrontage imputed
# LotArea imputed
# OverallQual imputed
# OverallCond imputed
# YearBuilt imputed
# YearRemodAdd imputed
# MasVnrArea imputed
# BsmtFinSF1 imputed
# BsmtFinSF2 imputed
# BsmtUnfSF imputed
# TotalBsmtSF imputed
# 1stFlrSF imputed
# 2ndFlrSF imputed
# LowQualFinSF imputed
# GrLivArea imputed
# BsmtFullBath imputed
# BsmtHalfBath imputed
# FullBath imputed
# HalfBath imputed
# BedroomAbvGr imputed
# KitchenAbvGr imputed
# TotRmsAbvGrd imputed
# Fireplaces imputed
# GarageYrBlt imputed
# GarageCars imputed
# GarageArea imputed
# WoodDeckSF imputed
# OpenPorchSF imputed
# EnclosedPorch imputed
# 3SsnPorch imputed
# ScreenPorch imputed
# PoolArea imputed
# MiscVal imputed
# MoSold imputed
# YrSold imputed

# %%
df[[x for x in numerical if x!='SalePrice']].isnull().any()
# Out:
# MSSubClass       False
# LotFrontage      False
# LotArea          False
# OverallQual      False
# OverallCond      False
# YearBuilt        False
# YearRemodAdd     False
# MasVnrArea       False
# BsmtFinSF1       False
# BsmtFinSF2       False
# BsmtUnfSF        False
# TotalBsmtSF      False
# 1stFlrSF         False
# 2ndFlrSF         False
# LowQualFinSF     False
# GrLivArea        False
# BsmtFullBath     False
# BsmtHalfBath     False
# FullBath         False
# HalfBath         False
# BedroomAbvGr     False
# KitchenAbvGr     False
# TotRmsAbvGrd     False
# Fireplaces       False
# GarageYrBlt      False
# GarageCars       False
# GarageArea       False
# WoodDeckSF       False
# OpenPorchSF      False
# EnclosedPorch    False
# 3SsnPorch        False
# ScreenPorch      False
# PoolArea         False
# MiscVal          False
# MoSold           False
# YrSold           False
# dtype: bool

# %%
os.chdir('../output_data')

# %%
df.to_csv('train_v03.csv')

# %%
df.isnull().any()
# Out:
# MSSubClass             False
# LotFrontage            False
# LotArea                False
# OverallQual            False
# OverallCond            False
# YearBuilt              False
# YearRemodAdd           False
# MasVnrArea             False
# BsmtFinSF1             False
# BsmtFinSF2             False
# BsmtUnfSF              False
# TotalBsmtSF            False
# 1stFlrSF               False
# 2ndFlrSF               False
# LowQualFinSF           False
# GrLivArea              False
# BsmtFullBath           False
# BsmtHalfBath           False
# FullBath               False
# HalfBath               False
# BedroomAbvGr           False
# KitchenAbvGr           False
# TotRmsAbvGrd           False
# Fireplaces             False
# GarageYrBlt            False
# GarageCars             False
# GarageArea             False
# WoodDeckSF             False
# OpenPorchSF            False
# EnclosedPorch          False
#                        ...
# GarageType_dum_0       False
# GarageType_dum_1       False
# GarageType_dum_2       False
# GarageFinish_dum_0     False
# GarageFinish_dum_1     False
# GarageFinish_dum_2     False
# GarageQual_dum_0       False
# GarageQual_dum_1       False
# GarageQual_dum_2       False
# GarageCond_dum_0       False
# GarageCond_dum_1       False
# GarageCond_dum_2       False
# PavedDrive_dum_0       False
# PavedDrive_dum_1       False
# PoolQC_dum_0           False
# PoolQC_dum_1           False
# PoolQC_dum_2           False
# Fence_dum_0            False
# Fence_dum_1            False
# Fence_dum_2            False
# MiscFeature_dum_0      False
# MiscFeature_dum_1      False
# MiscFeature_dum_2      False
# SaleType_dum_0         False
# SaleType_dum_1         False
# SaleType_dum_2         False
# SaleType_dum_3         False
# SaleCondition_dum_0    False
# SaleCondition_dum_1    False
# SaleCondition_dum_2    False
# Length: 166, dtype: bool
